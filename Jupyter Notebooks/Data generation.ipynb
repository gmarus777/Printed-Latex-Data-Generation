# %%
# Here we take care of paths.

from pathlib import Path
import os
print('Starting path:' + os.getcwd())
if os.getcwd()[-29:] == "Printed-Latex-Data-Generation":
    pass
else:
    PATH = Path().resolve().parents[0]
    os.chdir(PATH)

# make sure you are in Paragraph_to_Tex folder
print('Current path:' + os.getcwd())
# Out:
# Starting path:/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed_Generation_repo/Printed-Latex-Data-Generation/Jupyter Notebooks
# Current path:/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed_Generation_repo/Printed-Latex-Data-Generation

# %%
from Printed_Tex import Generate_Printed_Tex

# %%
Generate_Printed_Tex(download_tex_dataset=False,
                    generate_tex_formulas =False,
                     number_tex_formulas_to_generate =1,
                     generate_svg_images_from_tex = False,
                     generate_png_from_svg = True,
                    )
# Out:
# Turning svg into png...
# Warning: Option --without-gui= is deprecatedWarning: Option --without-gui= is deprecated
# Warning: Option --without-gui= is deprecated
# Warning: Option --without-gui= is deprecatedWarning: Option --without-gui= is deprecated
# Warning: Option --without-gui= is deprecated
#
# Warning: Option --without-gui= is deprecated
#
#
# ** (org.inkscape.Inkscape:94390): WARNING **: 17:11:20.028: Ignoring unrecognized CSS property: vertical-align
#
# ** (org.inkscape.Inkscape:94392): WARNING **: 17:11:20.035: Ignoring unrecognized CSS property: vertical-align
# Background RRGGBBAA: ffffffff
# Area 0:0:17963.8:2587.3 exported to 512 x 64 pixels (2.73617 dpi)
# Background RRGGBBAA: ffffffff
# Area 0:0:12625.8:2443.8 exported to 512 x 64 pixels (3.89298 dpi)
# Warning: Option --without-gui= is deprecatedWarning: Option --without-gui= is deprecated
#
#
# ** (org.inkscape.Inkscape:94386): WARNING **: 17:11:20.295: Ignoring unrecognized CSS property: vertical-align
# Background RRGGBBAA: ffffffff
# Area 0:0:17855.5:2085 exported to 512 x 64 pixels (2.75277 dpi)
# Warning: Option --without-gui= is deprecated
#
# ** (org.inkscape.Inkscape:94397): WARNING **: 17:11:20.491: Ignoring unrecognized CSS property: vertical-align
#
# ** (org.inkscape.Inkscape:94398): WARNING **: 17:11:20.491: Ignoring unrecognized CSS property: margin-bottom
#
# ** (org.inkscape.Inkscape:94398): WARNING **: 17:11:20.491: Ignoring unrecognized CSS property: vertical-align
# Background RRGGBBAA: ffffffff
# Area 0:0:19877.6:2515.6 exported to 512 x 64 pixels (2.47273 dpi)
# Background RRGGBBAA: ffffffff
# Area 0:0:30043.5:2659.1 exported to 512 x 64 pixels (1.63603 dpi)
#
# ** (org.inkscape.Inkscape:94385): WARNING **: 17:11:20.567: Ignoring unrecognized CSS property: vertical-align
# Background RRGGBBAA: ffffffff
# Area 0:0:19989.4:2659.1 exported to 512 x 64 pixels (2.4589 dpi)
# Warning: Option --without-gui= is deprecated
# Warning: Option --without-gui= is deprecated
#
# ** (org.inkscape.Inkscape:94399): WARNING **: 17:11:20.702: Ignoring unrecognized CSS property: vertical-align
# Background RRGGBBAA: ffffffff
# Area 0:0:21312.3:2802.6 exported to 512 x 64 pixels (2.30627 dpi)
# Warning: Option --without-gui= is deprecated
#
# ** (org.inkscape.Inkscape:94391): WARNING **: 17:11:20.848: Ignoring unrecognized CSS property: vertical-align
# Background RRGGBBAA: ffffffff
# Area 0:0:10482.9:2372 exported to 512 x 64 pixels (4.68878 dpi)
# Warning: Option --without-gui= is deprecated
#
# ** (org.inkscape.Inkscape:94400): WARNING **: 17:11:20.900: Ignoring unrecognized CSS property: vertical-align
#
# ** (org.inkscape.Inkscape:94401): WARNING **: 17:11:20.902: Ignoring unrecognized CSS property: vertical-align
# Background RRGGBBAA: ffffffff
# Area 0:0:22763.2:3520.2 exported to 512 x 64 pixels (2.15927 dpi)
# Background RRGGBBAA: ffffffff
# Area 0:0:24899.6:3017.9 exported to 512 x 64 pixels (1.97401 dpi)
#
# ** (org.inkscape.Inkscape:94403): WARNING **: 17:11:20.977: Ignoring unrecognized CSS property: vertical-align
# Background RRGGBBAA: ffffffff
# Area 0:0:12778.9:2515.6 exported to 512 x 64 pixels (3.84634 dpi)
# Warning: Option --without-gui= is deprecated
# Warning: Option --without-gui= is deprecated
# Warning: Option --without-gui= is deprecated
#
# ** (org.inkscape.Inkscape:94404): WARNING **: 17:11:21.123: Ignoring unrecognized CSS property: vertical-align
# Background RRGGBBAA: ffffffff
# Area 0:0:13895.4:2802.6 exported to 512 x 64 pixels (3.53729 dpi)
#
# ** (org.inkscape.Inkscape:94389): WARNING **: 17:11:21.133: Ignoring unrecognized CSS property: vertical-align
# Warning: Option --without-gui= is deprecated
# Background RRGGBBAA: ffffffff
# Area 0:0:16992.1:1654.5 exported to 512 x 64 pixels (2.89264 dpi)
#
# ** (org.inkscape.Inkscape:94408): WARNING **: 17:11:21.270: Ignoring unrecognized CSS property: vertical-align
# Background RRGGBBAA: ffffffff
# Area 0:0:10886:1869.7 exported to 512 x 64 pixels (4.51516 dpi)
# Warning: Option --without-gui= is deprecated
# Warning: Option --without-gui= is deprecated
#
# ** (org.inkscape.Inkscape:94409): WARNING **: 17:11:21.333: Ignoring unrecognized CSS property: vertical-align
#
# ** (org.inkscape.Inkscape:94410): WARNING **: 17:11:21.333: Ignoring unrecognized CSS property: vertical-align
# Background RRGGBBAA: ffffffff
# Area 0:0:19852.7:2659.1 exported to 512 x 64 pixels (2.47583 dpi)
# Background RRGGBBAA: ffffffff
# Area 0:0:16956.9:1439.2 exported to 512 x 64 pixels (2.89864 dpi)
#
# ** (org.inkscape.Inkscape:94412): WARNING **: 17:11:21.401: Ignoring unrecognized CSS property: vertical-align
# Background RRGGBBAA: ffffffff
# Area 0:0:8676.8:1510.9 exported to 512 x 64 pixels (5.66476 dpi)
#
# ** (org.inkscape.Inkscape:94388): WARNING **: 17:11:21.424: Ignoring unrecognized CSS property: vertical-align
# Background RRGGBBAA: ffffffff
# Area 0:0:14331.4:1654.5 exported to 512 x 64 pixels (3.42967 dpi)
# Warning: Option --without-gui= is deprecated
# Warning: Option --without-gui= is deprecated
# Warning: Option --without-gui= is deprecated
# Warning: Option --without-gui= is deprecated
#
# ** (org.inkscape.Inkscape:94413): WARNING **: 17:11:21.575: Ignoring unrecognized CSS property: vertical-align
#
# ** (org.inkscape.Inkscape:94414): WARNING **: 17:11:21.578: Ignoring unrecognized CSS property: vertical-align
# Warning: Option --without-gui= is deprecated
# Background RRGGBBAA: ffffffff
# Area 0:0:13106.7:1295.7 exported to 512 x 64 pixels (3.75014 dpi)
# Background RRGGBBAA: ffffffff
# Area 0:0:7009:2730.8 exported to 512 x 64 pixels (7.0127 dpi)
#
# ** (org.inkscape.Inkscape:94415): WARNING **: 17:11:21.712: Ignoring unrecognized CSS property: vertical-align
# Background RRGGBBAA: ffffffff
# Area 0:0:31833.8:1439.2 exported to 512 x 64 pixels (1.54402 dpi)
# Warning: Option --without-gui= is deprecated
# Warning: Option --without-gui= is deprecated
#
# ** (org.inkscape.Inkscape:94416): WARNING **: 17:11:21.783: Ignoring unrecognized CSS property: vertical-align
#
# ** (org.inkscape.Inkscape:94417): WARNING **: 17:11:21.784: Ignoring unrecognized CSS property: vertical-align
# Background RRGGBBAA: ffffffff
# Area 0:0:8867:1439.2 exported to 512 x 64 pixels (5.54325 dpi)
# Background RRGGBBAA: ffffffff
# Area 0:0:15514.8:6247 exported to 512 x 64 pixels (3.16807 dpi)
#
# ** (org.inkscape.Inkscape:94418): WARNING **: 17:11:21.843: Ignoring unrecognized CSS property: vertical-align
#
# ** (org.inkscape.Inkscape:94419): WARNING **: 17:11:21.843: Ignoring unrecognized CSS property: vertical-align
# Background RRGGBBAA: ffffffff
# Area 0:0:17472.4:1439.2 exported to 512 x 64 pixels (2.81312 dpi)
# Background RRGGBBAA: ffffffff
# Area 0:0:15823.9:2228.5 exported to 512 x 64 pixels (3.10619 dpi)
# Warning: Option --without-gui= is deprecated
# Warning: Option --without-gui= is deprecated
# Warning: Option --without-gui= is deprecated
# Warning: Option --without-gui= is deprecated
# Warning: Option --without-gui= is deprecated
#
# ** (org.inkscape.Inkscape:94420): WARNING **: 17:11:22.016: Ignoring unrecognized CSS property: vertical-align
#
# ** (org.inkscape.Inkscape:94421): WARNING **: 17:11:22.016: Ignoring unrecognized CSS property: vertical-align
# Background RRGGBBAA: ffffffff
# Area 0:0:8813.7:2659.1 exported to 512 x 64 pixels (5.57677 dpi)
# Background RRGGBBAA: ffffffff
# Area 0:0:26267.1:2659.1 exported to 512 x 64 pixels (1.87124 dpi)
#
# ** (org.inkscape.Inkscape:94423): WARNING **: 17:11:22.136: Ignoring unrecognized CSS property: vertical-align
# Background RRGGBBAA: ffffffff
# Area 0:0:11328.2:3304.9 exported to 512 x 64 pixels (4.33891 dpi)
# Warning: Option --without-gui= is deprecated
# Warning: Option --without-gui= is deprecated
#
# ** (org.inkscape.Inkscape:94424): WARNING **: 17:11:22.214: Ignoring unrecognized CSS property: vertical-align
#
# ** (org.inkscape.Inkscape:94425): WARNING **: 17:11:22.216: Ignoring unrecognized CSS property: vertical-align
# Background RRGGBBAA: ffffffff
# Area 0:0:15124.8:3376.7 exported to 512 x 64 pixels (3.24976 dpi)
# Background RRGGBBAA: ffffffff
# Area 0:0:28491.7:2515.6 exported to 512 x 64 pixels (1.72513 dpi)
#
# ** (org.inkscape.Inkscape:94427): WARNING **: 17:11:22.282: Ignoring unrecognized CSS property: vertical-align
#
# ** (org.inkscape.Inkscape:94426): WARNING **: 17:11:22.283: Ignoring unrecognized CSS property: vertical-align
# Background RRGGBBAA: ffffffff
# Area 0:0:14960.4:1223.9 exported to 512 x 64 pixels (3.28547 dpi)
# Background RRGGBBAA: ffffffff
# Area 0:0:16087.4:2874.4 exported to 512 x 64 pixels (3.05531 dpi)
# Warning: Option --without-gui= is deprecated
# Warning: Option --without-gui= is deprecated
# Warning: Option --without-gui= is deprecated
# Warning: Option --without-gui= is deprecated
# Warning: Option --without-gui= is deprecated
#
# ** (org.inkscape.Inkscape:94429): WARNING **: 17:11:22.470: Ignoring unrecognized CSS property: vertical-align
#
# ** (org.inkscape.Inkscape:94428): WARNING **: 17:11:22.473: Ignoring unrecognized CSS property: margin-top
#
# ** (org.inkscape.Inkscape:94428): WARNING **: 17:11:22.473: Ignoring unrecognized CSS property: vertical-align
# Background RRGGBBAA: ffffffff
# Area 0:0:10422.2:1367.4 exported to 512 x 64 pixels (4.71609 dpi)
# Background RRGGBBAA: ffffffff
# Area 0:0:29400.5:7825.7 exported to 512 x 64 pixels (1.67181 dpi)
#
# ** (org.inkscape.Inkscape:94430): WARNING **: 17:11:22.572: Ignoring unrecognized CSS property: vertical-align
# Background RRGGBBAA: ffffffff
# Area 0:0:21456.9:649.8 exported to 512 x 64 pixels (2.29073 dpi)
# Warning: Option --without-gui= is deprecated
#
# ** (org.inkscape.Inkscape:94431): WARNING **: 17:11:22.654: Ignoring unrecognized CSS property: vertical-align
#
# ** (org.inkscape.Inkscape:94432): WARNING **: 17:11:22.654: Ignoring unrecognized CSS property: vertical-align
# Background RRGGBBAA: ffffffff
# Area 0:0:8715.5:1582.7 exported to 512 x 64 pixels (5.63961 dpi)
# Background RRGGBBAA: ffffffff
# Area 0:0:17122.3:1295.7 exported to 512 x 64 pixels (2.87064 dpi)
# Warning: Option --without-gui= is deprecated
#
# ** (org.inkscape.Inkscape:94433): WARNING **: 17:11:22.712: Ignoring unrecognized CSS property: vertical-align
# Background RRGGBBAA: ffffffff
# Area 0:0:7498.4:1223.9 exported to 512 x 64 pixels (6.555 dpi)
#
# ** (org.inkscape.Inkscape:94434): WARNING **: 17:11:22.717: Ignoring unrecognized CSS property: vertical-align
# Background RRGGBBAA: ffffffff
# Area 0:0:8872.5:2659.1 exported to 512 x 64 pixels (5.53981 dpi)
# Warning: Option --without-gui= is deprecated
# Warning: Option --without-gui= is deprecated
# Warning: Option --without-gui= is deprecated
# Warning: Option --without-gui= is deprecated
# Warning: Option --without-gui= is deprecated
#
# ** (org.inkscape.Inkscape:94435): WARNING **: 17:11:22.897: Ignoring unrecognized CSS property: vertical-align
# Background RRGGBBAA: ffffffff
# Area 0:0:11485.5:1510.9 exported to 512 x 64 pixels (4.27948 dpi)
#
# ** (org.inkscape.Inkscape:94436): WARNING **: 17:11:22.952: Ignoring unrecognized CSS property: vertical-align
# Background RRGGBBAA: ffffffff
# Area 0:0:12992.6:1367.4 exported to 512 x 64 pixels (3.78308 dpi)
#
# ** (org.inkscape.Inkscape:94437): WARNING **: 17:11:23.005: Ignoring unrecognized CSS property: vertical-align
# Background RRGGBBAA: ffffffff
# Area 0:0:9842.7:1367.4 exported to 512 x 64 pixels (4.99375 dpi)
# Warning: Option --without-gui= is deprecated
#
# ** (org.inkscape.Inkscape:94439): WARNING **: 17:11:23.103: Ignoring unrecognized CSS property: vertical-align
# Warning: Option --without-gui= is deprecated
#
# ** (org.inkscape.Inkscape:94438): WARNING **: 17:11:23.107: Ignoring unrecognized CSS property: vertical-align
# Background RRGGBBAA: ffffffff
# Area 0:0:14212.4:2659.1 exported to 512 x 64 pixels (3.45839 dpi)
# Background RRGGBBAA: ffffffff
# Area 0:0:12421.7:1510.9 exported to 512 x 64 pixels (3.95695 dpi)
#
# ** (org.inkscape.Inkscape:94441): WARNING **: 17:11:23.141: Ignoring unrecognized CSS property: vertical-align
#
# ** (org.inkscape.Inkscape:94442): WARNING **: 17:11:23.141: Ignoring unrecognized CSS property: margin-left
#
# ** (org.inkscape.Inkscape:94442): WARNING **: 17:11:23.141: Ignoring unrecognized CSS property: vertical-align
# Background RRGGBBAA: ffffffff
# Area 0:0:7152.9:1439.2 exported to 512 x 64 pixels (6.87162 dpi)
# Background RRGGBBAA: ffffffff
# Area 0:0:23689.6:4094.3 exported to 512 x 64 pixels (2.07483 dpi)
# Warning: Option --without-gui= is deprecated
# Warning: Option --without-gui= is deprecated
# Warning: Option --without-gui= is deprecated
# Warning: Option --without-gui= is deprecated
# Warning: Option --without-gui= is deprecated
#
# ** (org.inkscape.Inkscape:94443): WARNING **: 17:11:23.325: Ignoring unrecognized CSS property: vertical-align
# Background RRGGBBAA: ffffffff
# Area 0:0:26018.6:1223.9 exported to 512 x 64 pixels (1.88911 dpi)
#
# ** (org.inkscape.Inkscape:94444): WARNING **: 17:11:23.381: Ignoring unrecognized CSS property: vertical-align
# Background RRGGBBAA: ffffffff
# Area 0:0:36681.8:3017.9 exported to 512 x 64 pixels (1.33996 dpi)
#
# ** (org.inkscape.Inkscape:94445): WARNING **: 17:11:23.424: Ignoring unrecognized CSS property: vertical-align
# Background RRGGBBAA: ffffffff
# Area 0:0:17989.6:1295.7 exported to 512 x 64 pixels (2.73225 dpi)
# Warning: Option --without-gui= is deprecated
#
# ** (org.inkscape.Inkscape:94447): WARNING **: 17:11:23.541: Ignoring unrecognized CSS property: vertical-align
# Background RRGGBBAA: ffffffff
# Area 0:0:10840.5:2659.1 exported to 512 x 64 pixels (4.53411 dpi)
#
# ** (org.inkscape.Inkscape:94446): WARNING **: 17:11:23.546: Ignoring unrecognized CSS property: vertical-align
# Warning: Option --without-gui= is deprecated
# Background RRGGBBAA: ffffffff
# Area 0:0:27598.1:3233.2 exported to 512 x 64 pixels (1.78099 dpi)
#
# ** (org.inkscape.Inkscape:94448): WARNING **: 17:11:23.569: Ignoring unrecognized CSS property: vertical-align
#
# ** (org.inkscape.Inkscape:94449): WARNING **: 17:11:23.570: Ignoring unrecognized CSS property: vertical-align
# Background RRGGBBAA: ffffffff
# Area 0:0:11962.1:2946.1 exported to 512 x 64 pixels (4.10898 dpi)
# Background RRGGBBAA: ffffffff
# Area 0:0:24139.3:1726.2 exported to 512 x 64 pixels (2.03618 dpi)
# Warning: Option --without-gui= is deprecated
# Warning: Option --without-gui= is deprecated
# Warning: Option --without-gui= is deprecated
# Warning: Option --without-gui= is deprecated
# Warning: Option --without-gui= is deprecated
#
# ** (org.inkscape.Inkscape:94450): WARNING **: 17:11:23.754: Ignoring unrecognized CSS property: vertical-align
# Background RRGGBBAA: ffffffff
# Area 0:0:21651.4:1510.9 exported to 512 x 64 pixels (2.27015 dpi)
#
# ** (org.inkscape.Inkscape:94451): WARNING **: 17:11:23.839: Ignoring unrecognized CSS property: vertical-align
# Background RRGGBBAA: ffffffff
# Area 0:0:12237.9:1223.9 exported to 512 x 64 pixels (4.01638 dpi)
#
# ** (org.inkscape.Inkscape:94452): WARNING **: 17:11:23.869: Ignoring unrecognized CSS property: vertical-align
# Background RRGGBBAA: ffffffff
# Area 0:0:26804.9:2874.4 exported to 512 x 64 pixels (1.83369 dpi)
# Warning: Option --without-gui= is deprecated
#
# ** (org.inkscape.Inkscape:94453): WARNING **: 17:11:23.987: Ignoring unrecognized CSS property: vertical-align
# Background RRGGBBAA: ffffffff
# Area 0:0:13567.6:2228.5 exported to 512 x 64 pixels (3.62275 dpi)
# Warning: Option --without-gui= is deprecated
#
# ** (org.inkscape.Inkscape:94454): WARNING **: 17:11:24.006: Ignoring unrecognized CSS property: vertical-align
#
# ** (org.inkscape.Inkscape:94456): WARNING **: 17:11:24.006: Ignoring unrecognized CSS property: vertical-align
#
# ** (org.inkscape.Inkscape:94455): WARNING **: 17:11:24.007: Ignoring unrecognized CSS property: vertical-align
# Background RRGGBBAA: ffffffff
# Area 0:0:25532:3089.6 exported to 512 x 64 pixels (1.92511 dpi)
# Background RRGGBBAA: ffffffff
# Area 0:0:25017.6:2587.3 exported to 512 x 64 pixels (1.9647 dpi)
# Background RRGGBBAA: ffffffff
# Area 0:0:29773.2:2443.8 exported to 512 x 64 pixels (1.65088 dpi)
# Warning: Option --without-gui= is deprecated
# Warning: Option --without-gui= is deprecated
# Warning: Option --without-gui= is deprecatedWarning: Option --without-gui= is deprecated
#
# Warning: Option --without-gui= is deprecated
#
# ** (org.inkscape.Inkscape:94458): WARNING **: 17:11:24.188: Ignoring unrecognized CSS property: vertical-align
# Background RRGGBBAA: ffffffff
# Area 0:0:16847.8:1295.7 exported to 512 x 64 pixels (2.91741 dpi)
#
# ** (org.inkscape.Inkscape:94459): WARNING **: 17:11:24.294: Ignoring unrecognized CSS property: vertical-align
# Background RRGGBBAA: ffffffff
# Area 0:0:14792.7:3735.5 exported to 512 x 64 pixels (3.32272 dpi)
#
# ** (org.inkscape.Inkscape:94460): WARNING **: 17:11:24.303: Ignoring unrecognized CSS property: vertical-align
# Background RRGGBBAA: ffffffff
# Area 0:0:14816.5:1367.4 exported to 512 x 64 pixels (3.31738 dpi)
# Warning: Option --without-gui= is deprecated
#
# ** (org.inkscape.Inkscape:94461): WARNING **: 17:11:24.406: Ignoring unrecognized CSS property: vertical-align
# Background RRGGBBAA: ffffffff
# Area 0:0:10129.3:2515.6 exported to 512 x 64 pixels (4.85246 dpi)
#
# ** (org.inkscape.Inkscape:94462): WARNING **: 17:11:24.448: Ignoring unrecognized CSS property: vertical-align
#
# ** (org.inkscape.Inkscape:94463): WARNING **: 17:11:24.448: Ignoring unrecognized CSS property: vertical-align
# Background RRGGBBAA: ffffffff
# Area 0:0:11649.7:2874.4 exported to 512 x 64 pixels (4.21916 dpi)
# Warning: Option --without-gui= is deprecatedWarning: Option --without-gui= is deprecated
#
# Background RRGGBBAA: ffffffff
# Area 0:0:22674.9:1439.2 exported to 512 x 64 pixels (2.16768 dpi)
#
# ** (org.inkscape.Inkscape:94464): WARNING **: 17:11:24.459: Ignoring unrecognized CSS property: vertical-align
# Background RRGGBBAA: ffffffff
# Area 0:0:10839.6:2228.5 exported to 512 x 64 pixels (4.53448 dpi)
# Warning: Option --without-gui= is deprecated
# Warning: Option --without-gui= is deprecatedWarning: Option --without-gui= is deprecated
#
#
# ** (org.inkscape.Inkscape:94465): WARNING **: 17:11:24.633: Ignoring unrecognized CSS property: vertical-align
# Warning: Option --without-gui= is deprecated
# Background RRGGBBAA: ffffffff
# Area 0:0:6787.8:2228.5 exported to 512 x 64 pixels (7.24123 dpi)
#
# ** (org.inkscape.Inkscape:94466): WARNING **: 17:11:24.739: Ignoring unrecognized CSS property: vertical-align
# Background RRGGBBAA: ffffffff
# Area 0:0:7278.6:1869.7 exported to 512 x 64 pixels (6.75295 dpi)
#
# ** (org.inkscape.Inkscape:94467): WARNING **: 17:11:24.744: Ignoring unrecognized CSS property: vertical-align
# Background RRGGBBAA: ffffffff
# Area 0:0:24400.2:2156.8 exported to 512 x 64 pixels (2.01441 dpi)
# Warning: Option --without-gui= is deprecated
#
# ** (org.inkscape.Inkscape:94468): WARNING **: 17:11:24.827: Ignoring unrecognized CSS property: vertical-align
# Background RRGGBBAA: ffffffff
# Area 0:0:13469.1:3161.4 exported to 512 x 64 pixels (3.64924 dpi)
#
# ** (org.inkscape.Inkscape:94470): WARNING **: 17:11:24.890: Ignoring unrecognized CSS property: vertical-align
#
# ** (org.inkscape.Inkscape:94469): WARNING **: 17:11:24.892: Ignoring unrecognized CSS property: vertical-align
# Background RRGGBBAA: ffffffff
# Area 0:0:7362.1:3161.4 exported to 512 x 64 pixels (6.67636 dpi)
# Warning: Option --without-gui= is deprecated
# Background RRGGBBAA: ffffffff
# Area 0:0:9744.8:1510.9 exported to 512 x 64 pixels (5.04392 dpi)
#
# ** (org.inkscape.Inkscape:94471): WARNING **: 17:11:24.907: Ignoring unrecognized CSS property: vertical-align
# Warning: Option --without-gui= is deprecated
# Background RRGGBBAA: ffffffff
# Area 0:0:14049.2:1367.4 exported to 512 x 64 pixels (3.49856 dpi)
# Warning: Option --without-gui= is deprecated
# Warning: Option --without-gui= is deprecated
# Warning: Option --without-gui= is deprecated
#
# ** (org.inkscape.Inkscape:94472): WARNING **: 17:11:25.062: Ignoring unrecognized CSS property: vertical-align
# Background RRGGBBAA: ffffffff
# Area 0:0:9600.2:1582.7 exported to 512 x 64 pixels (5.11989 dpi)
# Warning: Option --without-gui= is deprecated
#
# ** (org.inkscape.Inkscape:94473): WARNING **: 17:11:25.172: Ignoring unrecognized CSS property: vertical-align
# Background RRGGBBAA: ffffffff
# Area 0:0:9927.1:2659.1 exported to 512 x 64 pixels (4.9513 dpi)
#
# ** (org.inkscape.Inkscape:94474): WARNING **: 17:11:25.181: Ignoring unrecognized CSS property: vertical-align
# Background RRGGBBAA: ffffffff
# Area 0:0:18427.9:3376.7 exported to 512 x 64 pixels (2.66726 dpi)
# Warning: Option --without-gui= is deprecated
#
# ** (org.inkscape.Inkscape:94476): WARNING **: 17:11:25.256: Ignoring unrecognized CSS property: vertical-align
# Background RRGGBBAA: ffffffff
# Area 0:0:13537.3:2443.8 exported to 512 x 64 pixels (3.63086 dpi)
#
# ** (org.inkscape.Inkscape:94477): WARNING **: 17:11:25.323: Ignoring unrecognized CSS property: vertical-align
#
# ** (org.inkscape.Inkscape:94478): WARNING **: 17:11:25.324: Ignoring unrecognized CSS property: vertical-align
# Background RRGGBBAA: ffffffff
# Area 0:0:5156.7:1439.2 exported to 512 x 64 pixels (9.53168 dpi)
# Warning: Option --without-gui= is deprecated
# Background RRGGBBAA: ffffffff
# Area 0:0:22438:3161.4 exported to 512 x 64 pixels (2.19057 dpi)
#
# ** (org.inkscape.Inkscape:94479): WARNING **: 17:11:25.337: Ignoring unrecognized CSS property: vertical-align
# Background RRGGBBAA: ffffffff
# Area 0:0:12157.4:1295.7 exported to 512 x 64 pixels (4.04297 dpi)
# Warning: Option --without-gui= is deprecated
# Warning: Option --without-gui= is deprecated
# Warning: Option --without-gui= is deprecated
# Warning: Option --without-gui= is deprecated
#
# ** (org.inkscape.Inkscape:94480): WARNING **: 17:11:25.500: Ignoring unrecognized CSS property: vertical-align
# Warning: Option --without-gui= is deprecated
# Background RRGGBBAA: ffffffff
# Area 0:0:19318:2228.5 exported to 512 x 64 pixels (2.54436 dpi)
#
# ** (org.inkscape.Inkscape:94481): WARNING **: 17:11:25.604: Ignoring unrecognized CSS property: vertical-align
#
# ** (org.inkscape.Inkscape:94482): WARNING **: 17:11:25.604: Ignoring unrecognized CSS property: vertical-align
# Background RRGGBBAA: ffffffff
# Area 0:0:11233.2:2587.3 exported to 512 x 64 pixels (4.3756 dpi)
# Background RRGGBBAA: ffffffff
# Area 0:0:20217.3:3448.4 exported to 512 x 64 pixels (2.43119 dpi)
# Warning: Option --without-gui= is deprecated
#
# ** (org.inkscape.Inkscape:94483): WARNING **: 17:11:25.678: Ignoring unrecognized CSS property: vertical-align
# Background RRGGBBAA: ffffffff
# Area 0:0:30532.8:2659.1 exported to 512 x 64 pixels (1.60981 dpi)
#
# ** (org.inkscape.Inkscape:94485): WARNING **: 17:11:25.760: Ignoring unrecognized CSS property: vertical-align
#
# ** (org.inkscape.Inkscape:94484): WARNING **: 17:11:25.760: Ignoring unrecognized CSS property: vertical-align
#
# ** (org.inkscape.Inkscape:94486): WARNING **: 17:11:25.766: Ignoring unrecognized CSS property: vertical-align
# Background RRGGBBAA: ffffffff
# Area 0:0:20462:2372 exported to 512 x 64 pixels (2.40211 dpi)
# Background RRGGBBAA: ffffffff
# Area 0:0:27009.8:2443.8 exported to 512 x 64 pixels (1.81978 dpi)
# Warning: Option --without-gui= is deprecated
# Warning: Option --without-gui= is deprecated
# Background RRGGBBAA: ffffffff
# Area 0:0:12327.1:2443.8 exported to 512 x 64 pixels (3.98731 dpi)
# Warning: Option --without-gui= is deprecated
#
# ** (org.inkscape.Inkscape:94487): WARNING **: 17:11:25.935: Ignoring unrecognized CSS property: vertical-align
# Warning: Option --without-gui= is deprecated
# Warning: Option --without-gui= is deprecated
# Warning: Option --without-gui= is deprecated
# Background RRGGBBAA: ffffffff
# Area 0:0:19751.7:2659.1 exported to 512 x 64 pixels (2.48849 dpi)
#
# ** (org.inkscape.Inkscape:94488): WARNING **: 17:11:26.044: Ignoring unrecognized CSS property: vertical-align
#
# ** (org.inkscape.Inkscape:94489): WARNING **: 17:11:26.044: Ignoring unrecognized CSS property: vertical-align
# Background RRGGBBAA: ffffffff
# Area 0:0:10125.1:2515.6 exported to 512 x 64 pixels (4.85447 dpi)
# Background RRGGBBAA: ffffffff
# Area 0:0:18266.2:2874.4 exported to 512 x 64 pixels (2.69087 dpi)
#
# ** (org.inkscape.Inkscape:94490): WARNING **: 17:11:26.110: Ignoring unrecognized CSS property: vertical-align
# Warning: Option --without-gui= is deprecated
# Background RRGGBBAA: ffffffff
# Area 0:0:8385.1:1439.2 exported to 512 x 64 pixels (5.86183 dpi)
# Warning: Option --without-gui= is deprecated
# Warning: Option --without-gui= is deprecated
#
# ** (org.inkscape.Inkscape:94493): WARNING **: 17:11:26.214: Ignoring unrecognized CSS property: vertical-align
#
# ** (org.inkscape.Inkscape:94492): WARNING **: 17:11:26.214: Ignoring unrecognized CSS property: vertical-align
# Background RRGGBBAA: ffffffff
# Area 0:0:13792.1:4094.3 exported to 512 x 64 pixels (3.56378 dpi)
#
# ** (org.inkscape.Inkscape:94491): WARNING **: 17:11:26.222: Ignoring unrecognized CSS property: vertical-align
# Background RRGGBBAA: ffffffff
# Area 0:0:26307.3:1439.2 exported to 512 x 64 pixels (1.86838 dpi)
# Background RRGGBBAA: ffffffff
# Area 0:0:23288:1439.2 exported to 512 x 64 pixels (2.11061 dpi)
# Warning: Option --without-gui= is deprecated
#
# ** (org.inkscape.Inkscape:94495): WARNING **: 17:11:26.372: Ignoring unrecognized CSS property: vertical-align
# Background RRGGBBAA: ffffffff
# Area 0:0:6961.2:1367.4 exported to 512 x 64 pixels (7.06085 dpi)
# Warning: Option --without-gui= is deprecatedWarning: Option --without-gui= is deprecated
#
# Warning: Option --without-gui= is deprecated
#
# ** (org.inkscape.Inkscape:94496): WARNING **: 17:11:26.472: Ignoring unrecognized CSS property: vertical-align
#
# ** (org.inkscape.Inkscape:94497): WARNING **: 17:11:26.472: Ignoring unrecognized CSS property: vertical-align
# Background RRGGBBAA: ffffffff
# Area 0:0:12507.7:2659.1 exported to 512 x 64 pixels (3.92974 dpi)
# Background RRGGBBAA: ffffffff
# Area 0:0:21583.2:1510.9 exported to 512 x 64 pixels (2.27733 dpi)
#
# ** (org.inkscape.Inkscape:94498): WARNING **: 17:11:26.536: Ignoring unrecognized CSS property: vertical-align
# Background RRGGBBAA: ffffffff
# Area 0:0:4759.1:1869.7 exported to 512 x 64 pixels (10.328 dpi)
# Warning: Option --without-gui= is deprecated
# Warning: Option --without-gui= is deprecated
# Warning: Option --without-gui= is deprecated
#
# ** (org.inkscape.Inkscape:94499): WARNING **: 17:11:26.656: Ignoring unrecognized CSS property: vertical-align
#
# ** (org.inkscape.Inkscape:94501): WARNING **: 17:11:26.656: Ignoring unrecognized CSS property: vertical-align
#
# ** (org.inkscape.Inkscape:94500): WARNING **: 17:11:26.656: Ignoring unrecognized CSS property: vertical-align
# Background RRGGBBAA: ffffffff
# Area 0:0:7525.8:2013.3 exported to 512 x 64 pixels (6.53113 dpi)
# Background RRGGBBAA: ffffffff
# Area 0:0:13225.3:2587.3 exported to 512 x 64 pixels (3.71651 dpi)
# Background RRGGBBAA: ffffffff
# Area 0:0:15336.8:2730.8 exported to 512 x 64 pixels (3.20484 dpi)
# Warning: Option --without-gui= is deprecated
#
# ** (org.inkscape.Inkscape:94502): WARNING **: 17:11:26.815: Ignoring unrecognized CSS property: vertical-align
# Warning: Option --without-gui= is deprecated
# Warning: Option --without-gui= is deprecated
# Warning: Option --without-gui= is deprecated
# Background RRGGBBAA: ffffffff
# Area 0:0:11895.5:2730.8 exported to 512 x 64 pixels (4.13198 dpi)
#
# ** (org.inkscape.Inkscape:94503): WARNING **: 17:11:26.913: Ignoring unrecognized CSS property: vertical-align
#
# ** (org.inkscape.Inkscape:94504): WARNING **: 17:11:26.917: Ignoring unrecognized CSS property: vertical-align
# Background RRGGBBAA: ffffffff
# Area 0:0:10993.6:5385.9 exported to 512 x 64 pixels (4.47097 dpi)
# Background RRGGBBAA: ffffffff
# Area 0:0:26689.5:1439.2 exported to 512 x 64 pixels (1.84162 dpi)
#
# ** (org.inkscape.Inkscape:94505): WARNING **: 17:11:26.961: Ignoring unrecognized CSS property: vertical-align
# Background RRGGBBAA: ffffffff
# Area 0:0:20832.7:2372 exported to 512 x 64 pixels (2.35937 dpi)
# Warning: Option --without-gui= is deprecated
# Warning: Option --without-gui= is deprecated
# Warning: Option --without-gui= is deprecated
#
# ** (org.inkscape.Inkscape:94508): WARNING **: 17:11:27.103: Ignoring unrecognized CSS property: vertical-align
#
# ** (org.inkscape.Inkscape:94506): WARNING **: 17:11:27.103: Ignoring unrecognized CSS property: vertical-align
#
# ** (org.inkscape.Inkscape:94507): WARNING **: 17:11:27.104: Ignoring unrecognized CSS property: margin-left
#
# ** (org.inkscape.Inkscape:94507): WARNING **: 17:11:27.104: Ignoring unrecognized CSS property: vertical-align
# Background RRGGBBAA: ffffffff
# Area 0:0:12167.2:1510.9 exported to 512 x 64 pixels (4.03971 dpi)
# Background RRGGBBAA: ffffffff
# Area 0:0:16736.7:2802.6 exported to 512 x 64 pixels (2.93678 dpi)
# Background RRGGBBAA: ffffffff
# Area 0:0:25842.6:1367.4 exported to 512 x 64 pixels (1.90198 dpi)
# Warning: Option --without-gui= is deprecated
#
# ** (org.inkscape.Inkscape:94509): WARNING **: 17:11:27.252: Ignoring unrecognized CSS property: vertical-align
# Background RRGGBBAA: ffffffff
# Area 0:0:8056.3:2659.1 exported to 512 x 64 pixels (6.10106 dpi)
# Warning: Option --without-gui= is deprecated
# Warning: Option --without-gui= is deprecatedWarning: Option --without-gui= is deprecated
#
#
# ** (org.inkscape.Inkscape:94512): WARNING **: 17:11:27.340: Ignoring unrecognized CSS property: vertical-align
#
# ** (org.inkscape.Inkscape:94511): WARNING **: 17:11:27.341: Ignoring unrecognized CSS property: vertical-align
# Background RRGGBBAA: ffffffff
# Area 0:0:6845.5:5529.4 exported to 512 x 64 pixels (7.18019 dpi)
# Background RRGGBBAA: ffffffff
# Area 0:0:18403:1295.7 exported to 512 x 64 pixels (2.67087 dpi)
#
# ** (org.inkscape.Inkscape:94513): WARNING **: 17:11:27.395: Ignoring unrecognized CSS property: vertical-align
# Background RRGGBBAA: ffffffff
# Area 0:0:10081.4:2372 exported to 512 x 64 pixels (4.87551 dpi)
# Warning: Option --without-gui= is deprecated
# Warning: Option --without-gui= is deprecated
# Warning: Option --without-gui= is deprecated
#
# ** (org.inkscape.Inkscape:94516): WARNING **: 17:11:27.552: Ignoring unrecognized CSS property: vertical-align
#
# ** (org.inkscape.Inkscape:94515): WARNING **: 17:11:27.556: Ignoring unrecognized CSS property: vertical-align
# Background RRGGBBAA: ffffffff
# Area 0:0:20671.9:2659.1 exported to 512 x 64 pixels (2.37772 dpi)
#
# ** (org.inkscape.Inkscape:94514): WARNING **: 17:11:27.560: Ignoring unrecognized CSS property: vertical-align
# Background RRGGBBAA: ffffffff
# Area 0:0:31238.6:2443.8 exported to 512 x 64 pixels (1.57344 dpi)
# Warning: Option --without-gui= is deprecated
# Background RRGGBBAA: ffffffff
# Area 0:0:13200.9:2802.6 exported to 512 x 64 pixels (3.72338 dpi)
#
# ** (org.inkscape.Inkscape:94517): WARNING **: 17:11:27.684: Ignoring unrecognized CSS property: vertical-align
# Background RRGGBBAA: ffffffff
# Area 0:0:9062.4:1367.4 exported to 512 x 64 pixels (5.42373 dpi)
# Warning: Option --without-gui= is deprecated
# Warning: Option --without-gui= is deprecated
# Warning: Option --without-gui= is deprecated
#
# ** (org.inkscape.Inkscape:94518): WARNING **: 17:11:27.766: Ignoring unrecognized CSS property: vertical-align
#
# ** (org.inkscape.Inkscape:94519): WARNING **: 17:11:27.768: Ignoring unrecognized CSS property: vertical-align
# Background RRGGBBAA: ffffffff
# Area 0:0:11380.7:1869.7 exported to 512 x 64 pixels (4.31889 dpi)
# Background RRGGBBAA: ffffffff
# Area 0:0:25402.2:1439.2 exported to 512 x 64 pixels (1.93495 dpi)
#
# ** (org.inkscape.Inkscape:94520): WARNING **: 17:11:27.843: Ignoring unrecognized CSS property: vertical-align
# Warning: Option --without-gui= is deprecated
# Background RRGGBBAA: ffffffff
# Area 0:0:30373.7:2659.1 exported to 512 x 64 pixels (1.61824 dpi)
# Warning: Option --without-gui= is deprecated
# Warning: Option --without-gui= is deprecated
#
# ** (org.inkscape.Inkscape:94521): WARNING **: 17:11:28.000: Ignoring unrecognized CSS property: vertical-align
#
# ** (org.inkscape.Inkscape:94523): WARNING **: 17:11:28.000: Ignoring unrecognized CSS property: vertical-align
# Background RRGGBBAA: ffffffff
# Area 0:0:9345.4:1367.4 exported to 512 x 64 pixels (5.25949 dpi)
# Background RRGGBBAA: ffffffff
# Area 0:0:22058.7:1367.4 exported to 512 x 64 pixels (2.22824 dpi)
#
# ** (org.inkscape.Inkscape:94522): WARNING **: 17:11:28.009: Ignoring unrecognized CSS property: vertical-align
# Background RRGGBBAA: ffffffff
# Area 0:0:22935:1582.7 exported to 512 x 64 pixels (2.1431 dpi)
# Warning: Option --without-gui= is deprecated
#
# ** (org.inkscape.Inkscape:94524): WARNING **: 17:11:28.112: Ignoring unrecognized CSS property: vertical-align
# Background RRGGBBAA: ffffffff
# Area 0:0:23349.3:2587.3 exported to 512 x 64 pixels (2.10507 dpi)
# Warning: Option --without-gui= is deprecated
# Warning: Option --without-gui= is deprecated
# Warning: Option --without-gui= is deprecated
#
# ** (org.inkscape.Inkscape:94526): WARNING **: 17:11:28.211: Ignoring unrecognized CSS property: vertical-align
#
# ** (org.inkscape.Inkscape:94525): WARNING **: 17:11:28.212: Ignoring unrecognized CSS property: vertical-align
# Background RRGGBBAA: ffffffff
# Area 0:0:15516.9:1367.4 exported to 512 x 64 pixels (3.16764 dpi)
# Background RRGGBBAA: ffffffff
# Area 0:0:22637.4:2587.3 exported to 512 x 64 pixels (2.17127 dpi)
# Warning: Option --without-gui= is deprecated
#
# ** (org.inkscape.Inkscape:94527): WARNING **: 17:11:28.303: Ignoring unrecognized CSS property: vertical-align
# Background RRGGBBAA: ffffffff
# Area 0:0:21069.6:1439.2 exported to 512 x 64 pixels (2.33284 dpi)
# Warning: Option --without-gui= is deprecated
# Warning: Option --without-gui= is deprecated
#
# ** (org.inkscape.Inkscape:94529): WARNING **: 17:11:28.450: Ignoring unrecognized CSS property: vertical-align
#
# ** (org.inkscape.Inkscape:94531): WARNING **: 17:11:28.450: Ignoring unrecognized CSS property: vertical-align
#
# ** (org.inkscape.Inkscape:94530): WARNING **: 17:11:28.450: Ignoring unrecognized CSS property: vertical-align
# Background RRGGBBAA: ffffffff
# Area 0:0:13259.4:3233.2 exported to 512 x 64 pixels (3.70695 dpi)
# Background RRGGBBAA: ffffffff
# Area 0:0:18216.1:2085 exported to 512 x 64 pixels (2.69827 dpi)
# Background RRGGBBAA: ffffffff
# Area 0:0:24645.7:2515.6 exported to 512 x 64 pixels (1.99434 dpi)
# Warning: Option --without-gui= is deprecated
#
# ** (org.inkscape.Inkscape:94532): WARNING **: 17:11:28.542: Ignoring unrecognized CSS property: vertical-align
# Background RRGGBBAA: ffffffff
# Area 0:0:23322.6:1439.2 exported to 512 x 64 pixels (2.10748 dpi)
# Warning: Option --without-gui= is deprecatedWarning: Option --without-gui= is deprecated
#
# Warning: Option --without-gui= is deprecated
#
# ** (org.inkscape.Inkscape:94533): WARNING **: 17:11:28.637: Ignoring unrecognized CSS property: vertical-align
#
# ** (org.inkscape.Inkscape:94534): WARNING **: 17:11:28.637: Ignoring unrecognized CSS property: vertical-align
# Background RRGGBBAA: ffffffff
# Area 0:0:13527.5:1367.4 exported to 512 x 64 pixels (3.63349 dpi)
# Background RRGGBBAA: ffffffff
# Area 0:0:24350.3:3663.7 exported to 512 x 64 pixels (2.01854 dpi)
# Warning: Option --without-gui= is deprecated
#
# ** (org.inkscape.Inkscape:94535): WARNING **: 17:11:28.751: Ignoring unrecognized CSS property: vertical-align
# Background RRGGBBAA: ffffffff
# Area 0:0:6432:1726.2 exported to 512 x 64 pixels (7.64179 dpi)
# Warning: Option --without-gui= is deprecated
# Warning: Option --without-gui= is deprecated
#
# ** (org.inkscape.Inkscape:94537): WARNING **: 17:11:28.893: Ignoring unrecognized CSS property: vertical-align
# Background RRGGBBAA: ffffffff
# Area 0:0:11392.4:1367.4 exported to 512 x 64 pixels (4.31446 dpi)
#
# ** (org.inkscape.Inkscape:94538): WARNING **: 17:11:28.898: Ignoring unrecognized CSS property: vertical-align
#
# ** (org.inkscape.Inkscape:94536): WARNING **: 17:11:28.901: Ignoring unrecognized CSS property: vertical-align
# Warning: Option --without-gui= is deprecated
# Background RRGGBBAA: ffffffff
# Area 0:0:21852.8:2730.8 exported to 512 x 64 pixels (2.24923 dpi)
# Background RRGGBBAA: ffffffff
# Area 0:0:34455.2:2730.8 exported to 512 x 64 pixels (1.42655 dpi)
#
# ** (org.inkscape.Inkscape:94539): WARNING **: 17:11:28.979: Ignoring unrecognized CSS property: vertical-align
# Background RRGGBBAA: ffffffff
# Area 0:0:11221.1:1439.2 exported to 512 x 64 pixels (4.38032 dpi)
# Warning: Option --without-gui= is deprecated
# Warning: Option --without-gui= is deprecated
# Warning: Option --without-gui= is deprecated
#
# ** (org.inkscape.Inkscape:94540): WARNING **: 17:11:29.089: Ignoring unrecognized CSS property: vertical-align
#
# ** (org.inkscape.Inkscape:94541): WARNING **: 17:11:29.089: Ignoring unrecognized CSS property: vertical-align
# Background RRGGBBAA: ffffffff
# Area 0:0:5668.2:1367.4 exported to 512 x 64 pixels (8.67154 dpi)
# Background RRGGBBAA: ffffffff
# Area 0:0:28874.5:2443.8 exported to 512 x 64 pixels (1.70226 dpi)
# Warning: Option --without-gui= is deprecated
#
# ** (org.inkscape.Inkscape:94542): WARNING **: 17:11:29.180: Ignoring unrecognized CSS property: vertical-align
# Background RRGGBBAA: ffffffff
# Area 0:0:23838.6:2659.1 exported to 512 x 64 pixels (2.06187 dpi)
# Warning: Option --without-gui= is deprecated
# Warning: Option --without-gui= is deprecated
#
# ** (org.inkscape.Inkscape:94543): WARNING **: 17:11:29.339: Ignoring unrecognized CSS property: vertical-align
# Background RRGGBBAA: ffffffff
# Area 0:0:23036.7:1223.9 exported to 512 x 64 pixels (2.13364 dpi)
# Warning: Option --without-gui= is deprecated
#
# ** (org.inkscape.Inkscape:94545): WARNING **: 17:11:29.349: Ignoring unrecognized CSS property: vertical-align
#
# ** (org.inkscape.Inkscape:94544): WARNING **: 17:11:29.350: Ignoring unrecognized CSS property: vertical-align
# Background RRGGBBAA: ffffffff
# Area 0:0:9223.4:1582.7 exported to 512 x 64 pixels (5.32905 dpi)
# Background RRGGBBAA: ffffffff
# Area 0:0:31209.8:2659.1 exported to 512 x 64 pixels (1.57489 dpi)
#
# ** (org.inkscape.Inkscape:94546): WARNING **: 17:11:29.408: Ignoring unrecognized CSS property: vertical-align
# Background RRGGBBAA: ffffffff
# Area 0:0:17224.5:1223.9 exported to 512 x 64 pixels (2.85361 dpi)
# Warning: Option --without-gui= is deprecated
# Warning: Option --without-gui= is deprecated
#
# ** (org.inkscape.Inkscape:94549): WARNING **: 17:11:29.519: Ignoring unrecognized CSS property: vertical-align
#
# ** (org.inkscape.Inkscape:94548): WARNING **: 17:11:29.520: Ignoring unrecognized CSS property: vertical-align
# Warning: Option --without-gui= is deprecated
# Background RRGGBBAA: ffffffff
# Area 0:0:18490.4:3161.4 exported to 512 x 64 pixels (2.65824 dpi)
# Background RRGGBBAA: ffffffff
# Area 0:0:16836.8:4524.8 exported to 512 x 64 pixels (2.91932 dpi)
# Warning: Option --without-gui= is deprecated
#
# ** (org.inkscape.Inkscape:94550): WARNING **: 17:11:29.633: Ignoring unrecognized CSS property: vertical-align
# Background RRGGBBAA: ffffffff
# Area 0:0:18722.2:2587.3 exported to 512 x 64 pixels (2.62533 dpi)
# Warning: Option --without-gui= is deprecated
# Warning: Option --without-gui= is deprecated
#
# ** (org.inkscape.Inkscape:94551): WARNING **: 17:11:29.786: Ignoring unrecognized CSS property: vertical-align
#
# ** (org.inkscape.Inkscape:94552): WARNING **: 17:11:29.788: Ignoring unrecognized CSS property: vertical-align
#
# ** (org.inkscape.Inkscape:94553): WARNING **: 17:11:29.789: Ignoring unrecognized CSS property: vertical-align
# Background RRGGBBAA: ffffffff
# Area 0:0:24061.7:2730.8 exported to 512 x 64 pixels (2.04275 dpi)
# Background RRGGBBAA: ffffffff
# Area 0:0:13727.6:2659.1 exported to 512 x 64 pixels (3.58052 dpi)
# Background RRGGBBAA: ffffffff
# Area 0:0:14697.5:1439.2 exported to 512 x 64 pixels (3.34424 dpi)
# Warning: Option --without-gui= is deprecated
#
# ** (org.inkscape.Inkscape:94554): WARNING **: 17:11:29.829: Ignoring unrecognized CSS property: vertical-align
# Background RRGGBBAA: ffffffff
# Area 0:0:22588.8:4955.4 exported to 512 x 64 pixels (2.17595 dpi)
# Warning: Option --without-gui= is deprecated
# Warning: Option --without-gui= is deprecated
# Warning: Option --without-gui= is deprecated
#
# ** (org.inkscape.Inkscape:94556): WARNING **: 17:11:29.967: Ignoring unrecognized CSS property: vertical-align
# Background RRGGBBAA: ffffffff
# Area 0:0:11648.5:2659.1 exported to 512 x 64 pixels (4.2196 dpi)
#
# ** (org.inkscape.Inkscape:94555): WARNING **: 17:11:29.978: Ignoring unrecognized CSS property: vertical-align
# Background RRGGBBAA: ffffffff
# Area 0:0:8989.9:1367.4 exported to 512 x 64 pixels (5.46747 dpi)
# Warning: Option --without-gui= is deprecated
#
# ** (org.inkscape.Inkscape:94557): WARNING **: 17:11:30.077: Ignoring unrecognized CSS property: margin-bottom
#
# ** (org.inkscape.Inkscape:94557): WARNING **: 17:11:30.077: Ignoring unrecognized CSS property: vertical-align
# Background RRGGBBAA: ffffffff
# Area 0:0:19134.8:3089.6 exported to 512 x 64 pixels (2.56872 dpi)
# Warning: Option --without-gui= is deprecated
# Warning: Option --without-gui= is deprecated
#
# ** (org.inkscape.Inkscape:94559): WARNING **: 17:11:30.241: Ignoring unrecognized CSS property: vertical-align
#
# ** (org.inkscape.Inkscape:94560): WARNING **: 17:11:30.242: Ignoring unrecognized CSS property: vertical-align
# Background RRGGBBAA: ffffffff
# Area 0:0:4560.2:1223.9 exported to 512 x 64 pixels (10.7785 dpi)
#
# ** (org.inkscape.Inkscape:94561): WARNING **: 17:11:30.246: Ignoring unrecognized CSS property: vertical-align
#
# ** (org.inkscape.Inkscape:94558): WARNING **: 17:11:30.249: Ignoring unrecognized CSS property: vertical-align
# Background RRGGBBAA: ffffffff
# Area 0:0:37965.8:1439.2 exported to 512 x 64 pixels (1.29464 dpi)
# Background RRGGBBAA: ffffffff
# Area 0:0Warning: Option --without-gui= is deprecated:15283.8
# :2443.8 exported to 512 x 64 pixels (3.21595 dpi)
# Background RRGGBBAA: ffffffff
# Area 0:0:14427.6:2372 exported to 512 x 64 pixels (3.4068 dpi)
# Warning: Option --without-gui= is deprecated
# Warning: Option --without-gui= is deprecated
# Warning: Option --without-gui= is deprecated
# Warning: Option --without-gui= is deprecated
#
# ** (org.inkscape.Inkscape:94562): WARNING **: 17:11:30.422: Ignoring unrecognized CSS property: vertical-align
# Background RRGGBBAA: ffffffff
# Area 0:0:9986.6:2013.3 exported to 512 x 64 pixels (4.9218 dpi)
#
# ** (org.inkscape.Inkscape:94563): WARNING **: 17:11:30.457: Ignoring unrecognized CSS property: vertical-align
# Background RRGGBBAA: ffffffff
# Area 0:0:19016.3:3233.2 exported to 512 x 64 pixels (2.58473 dpi)
#
# ** (org.inkscape.Inkscape:94564): WARNING **: 17:11:30.535: Ignoring unrecognized CSS property: vertical-align
# Background RRGGBBAA: ffffffff
# Area 0:0:9623.3:5385.9 exported to 512 x 64 pixels (5.1076 dpi)
# Warning: Option --without-gui= is deprecated
# Warning: Option --without-gui= is deprecated
#
# ** (org.inkscape.Inkscape:94566): WARNING **: 17:11:30.688: Ignoring unrecognized CSS property: vertical-align
# Background RRGGBBAA: ffffffff
# Area 0:0:6801.5:1367.4 exported to 512 x 64 pixels (7.22664 dpi)
#
# ** (org.inkscape.Inkscape:94567): WARNING **: 17:11:30.691: Ignoring unrecognized CSS property: vertical-align
#
# ** (org.inkscape.Inkscape:94568): WARNING **: 17:11:30.691: Ignoring unrecognized CSS property: vertical-align
#
# ** (org.inkscape.Inkscape:94569): WARNING **: 17:11:30.692: Ignoring unrecognized CSS property: vertical-align
# Warning: Option --without-gui= is deprecated
# Background RRGGBBAA: ffffffff
# Area 0:0:14939.9:2730.8 exported to 512 x 64 pixels (3.28998 dpi)
# Background RRGGBBAA: ffffffff
# Area 0:0:18759.9:2587.3 exported to 512 x 64 pixels (2.62006 dpi)
# Background RRGGBBAA: ffffffff
# Area 0:0:25934.6:1510.9 exported to 512 x 64 pixels (1.89523 dpi)
# Warning: Option --without-gui= is deprecatedWarning: Option --without-gui= is deprecated
#
# Warning: Option --without-gui= is deprecated
# Warning: Option --without-gui= is deprecated
#
# ** (org.inkscape.Inkscape:94570): WARNING **: 17:11:30.882: Ignoring unrecognized CSS property: vertical-align
#
# ** (org.inkscape.Inkscape:94571): WARNING **: 17:11:30.882: Ignoring unrecognized CSS property: vertical-align
# Background RRGGBBAA: ffffffff
# Area 0:0:11879.1:1439.2 exported to 512 x 64 pixels (4.13769 dpi)
# Background RRGGBBAA: ffffffff
# Area 0:0:16258.6:2587.3 exported to 512 x 64 pixels (3.02314 dpi)
# ** (org.inkscape.Inkscape:94572): WARNING **: 17:11:30.965: Ignoring unrecognized CSS property: vertical-align
# Background RRGGBBAA: ffffffff
# Area 0:0:42202.7:2659.1 exported to 512 x 64 pixels (1.16466 dpi)
# Warning: Option --without-gui= is deprecated
# Warning: Option --without-gui= is deprecated
# Warning: Option --without-gui= is deprecated
#
# ** (org.inkscape.Inkscape:94574): WARNING **: 17:11:31.143: Ignoring unrecognized CSS property: vertical-align
#
# ** (org.inkscape.Inkscape:94573): WARNING **: 17:11:31.143: Ignoring unrecognized CSS property: vertical-align
#
# ** (org.inkscape.Inkscape:94576): WARNING **: 17:11:31.145: Ignoring unrecognized CSS property: vertical-align
#
# ** (org.inkscape.Inkscape:94575): WARNING **: 17:11:31.146: Ignoring unrecognized CSS property: vertical-align
# Background RRGGBBAA: ffffffff
# Area 0:0:7328.9:2443.8 exported to 512 x 64 pixels (6.7066 dpi)
# Background RRGGBBAA: ffffffff
# Area 0:0Background RRGGBBAA: :18370.2ffffffff:
# 2874.4Area 0 exported to 512:0: x 27362.664: pixels (2443.8 exported to 5122.67564 dpi)
#  x 64 pixels (1.79632 dpi)
# Background RRGGBBAA: ffffffff
# Area 0:0:29677.1:2802.6 exported to 512 x 64 pixels (1.65623 dpi)
# Warning: Option --without-gui= is deprecated
# Warning: Option --without-gui= is deprecated
# Warning: Option --without-gui= is deprecated
# Warning: Option --without-gui= is deprecated
#
# ** (org.inkscape.Inkscape:94577): WARNING **: 17:11:31.320: Ignoring unrecognized CSS property: vertical-align
#
# ** (org.inkscape.Inkscape:94578): WARNING **: 17:11:31.320: Ignoring unrecognized CSS property: vertical-align
# Background RRGGBBAA: ffffffff
# Area 0:0:14194.6:2228.5 exported to 512 x 64 pixels (3.46273 dpi)
# Background RRGGBBAA: ffffffff
# Area 0:0:17817.9:2802.6 exported to 512 x 64 pixels (2.75857 dpi)
#
# ** (org.inkscape.Inkscape:94579): WARNING **: 17:11:31.425: Ignoring unrecognized CSS property: vertical-align
# Background RRGGBBAA: ffffffff
# Area 0:0:12152.6:2372 exported to 512 x 64 pixels (4.04457 dpi)
# Warning: Option --without-gui= is deprecated
# Warning: Option --without-gui= is deprecated
# Warning: Option --without-gui= is deprecated
#
# ** (org.inkscape.Inkscape:94583): WARNING **: 17:11:31.610: Ignoring unrecognized CSS property: vertical-align
#
# ** (org.inkscape.Inkscape:94581): WARNING **: 17:11:31.610: Ignoring unrecognized CSS property: vertical-align
#
# ** (org.inkscape.Inkscape:94582): WARNING **: 17:11:31.611: Ignoring unrecognized CSS property: vertical-align
# Background RRGGBBAA: ffffffff
# Area 0:0:13051.1:2659.1 exported to 512 x 64 pixels (3.76612 dpi)
# Background RRGGBBAA: ffffffff
# Area 0:0:11165.4:1798 exported to 512 x 64 pixels (4.40217 dpi)
# Background RRGGBBAA: ffffffff
# Area 0:0:13521.8:2228.5 exported to 512 x 64 pixels (3.63502 dpi)
#
# ** (org.inkscape.Inkscape:94584): WARNING **: 17:11:31.668: Ignoring unrecognized CSS property: vertical-align
# Background RRGGBBAA: ffffffff
# Area 0:0:12329.1:2515.6 exported to 512 x 64 pixels (3.98667 dpi)
# Warning: Option --without-gui= is deprecated
# Warning: Option --without-gui= is deprecated
# Warning: Option --without-gui= is deprecated
#
# ** (org.inkscape.Inkscape:94585): WARNING **: 17:11:31.799: Ignoring unrecognized CSS property: vertical-align
#
# ** (org.inkscape.Inkscape:94586): WARNING **: 17:11:31.800: Ignoring unrecognized CSS property: vertical-align
# Background RRGGBBAA: Background RRGGBBAA: ffffffffffffffff
#
# Area Area 0:0:0:0:13992.2:16325.7:2228.5 exported to 2515.6 exported to 512512 x  x 6464 pixels ( pixels (3.01071 dpi)3.51281
#  dpi)
# Warning: Option --without-gui= is deprecated
#
# ** (org.inkscape.Inkscape:94587): WARNING **: 17:11:31.853: Ignoring unrecognized CSS property: vertical-align
# Background RRGGBBAA: ffffffff
# Area 0:0:17986.3:2443.8 exported to 512 x 64 pixels (2.73275 dpi)
# Warning: Option --without-gui= is deprecated
# Warning: Option --without-gui= is deprecated
# Warning: Option --without-gui= is deprecated
#
# ** (org.inkscape.Inkscape:94591): WARNING **: 17:11:32.047: Ignoring unrecognized CSS property: vertical-align
#
# ** (org.inkscape.Inkscape:94590): WARNING **: 17:11:32.048: Ignoring unrecognized CSS property: vertical-align
# Background RRGGBBAA: ffffffff
# Area 0:0:24580.8:3161.4 exported to 512 x 64 pixels (1.99961 dpi)
# Background RRGGBBAA: ffffffff
# Area 0:0:29009.6:2730.8 exported to 512 x 64 pixels (1.69434 dpi)
#
# ** (org.inkscape.Inkscape:94592): WARNING **: 17:11:32.102: Ignoring unrecognized CSS property: vertical-align
# Background RRGGBBAA: ffffffff
# Area 0:0:16742.3:2085 exported to 512 x 64 pixels (2.9358 dpi)
#
# ** (org.inkscape.Inkscape:94589): WARNING **: 17:11:32.124: Ignoring unrecognized CSS property: vertical-align
# Background RRGGBBAA: ffffffff
# Area 0:0:18817.7:2802.6 exported to 512 x 64 pixels (2.61201 dpi)
# Warning: Option --without-gui= is deprecated
# ...
# Background RRGGBBAA: ffffffff
# Area 0:0:15837.3:2946.1 exported to 512 x 64 pixels (3.10356 dpi)
# Background RRGGBBAA: ffffffff
# Area 0:0:32202.8:2085 exported to 512 x 64 pixels (1.52633 dpi)
#
# ** (org.inkscape.Inkscape:94726): WARNING **: 17:11:39.902: Ignoring unrecognized CSS property: vertical-align
# Background RRGGBBAA: ffffffff
# Area 0:0:15865.8:4237.8 exported to 512 x 64 pixels (3.09798 dpi)
# Background RRGGBBAA: ffffffff
# Area 0:0:20835.3:2802.6 exported to 512 x 64 pixels (2.35907 dpi)
# Warning: Option --without-gui= is deprecated
# Warning: Option --without-gui= is deprecated
# Warning: Option --without-gui= is deprecated
#
# ** (org.inkscape.Inkscape:94730): WARNING **: 17:11:40.153: Ignoring unrecognized CSS property: vertical-align
#
# ** (org.inkscape.Inkscape:94728): WARNING **: 17:11:40.153: Ignoring unrecognized CSS property: vertical-align
#
# ** (org.inkscape.Inkscape:94729): WARNING **: 17:11:40.157: Ignoring unrecognized CSS property: vertical-align
# Background RRGGBBAA: ffffffff
# Area 0:0:11603.6:2443.8 exported to 512 x 64 pixels (4.23593 dpi)
# Background RRGGBBAA: ffffffff
# Area 0:0:12552:2228.5 exported to 512 x 64 pixels (3.91587 dpi)
# Background RRGGBBAA: ffffffff
# Area 0:0:12370.8:1367.4 exported to 512 x 64 pixels (3.97323 dpi)
# Warning: Option --without-gui= is deprecated
# Warning: Option --without-gui= is deprecated
# Warning: Option --without-gui= is deprecated
#
# ** (org.inkscape.Inkscape:94733): WARNING **: 17:11:40.333: Ignoring unrecognized CSS property: vertical-align
#
# ** (org.inkscape.Inkscape:94731): WARNING **: 17:11:40.334: Ignoring unrecognized CSS property: vertical-align
#
# ** (org.inkscape.Inkscape:94732): WARNING **: 17:11:40.336: Ignoring unrecognized CSS property: vertical-align
# Background RRGGBBAA: ffffffff
# Area 0:0:9664.2:1295.7 exported to 512 x 64 pixels (5.08599 dpi)
# Background RRGGBBAA: ffffffff
# Area 0:0:7590.2:1367.4 exported to 512 x 64 pixels (6.47572 dpi)
# Background RRGGBBAA: ffffffff
# Area 0:0:18935.1:2946.1 exported to 512 x 64 pixels (2.59581 dpi)
# Warning: Option --without-gui= is deprecatedWarning: Option --without-gui= is deprecated
#
# Warning: Option --without-gui= is deprecated
#
# ** (org.inkscape.Inkscape:94737): WARNING **: 17:11:40.599: Ignoring unrecognized CSS property: vertical-align
#
# ** (org.inkscape.Inkscape:94738): WARNING **: 17:11:40.601: Ignoring unrecognized CSS property: vertical-align
#
# ** (org.inkscape.Inkscape:94736): WARNING **: 17:11:40.605: Ignoring unrecognized CSS property: vertical-align
# Background RRGGBBAA: ffffffff
# Area 0:0:18952:2659.1 exported to 512 x 64 pixels (2.5935 dpi)
# Background RRGGBBAA: ffffffff
# Area 0:0:19443.2:2085 exported to 512 x 64 pixels (2.52798 dpi)
# Background RRGGBBAA: ffffffff
# Area 0:0:15764.7:1223.9 exported to 512 x 64 pixels (3.11785 dpi)
# Warning: Option --without-gui= is deprecated
# Warning: Option --without-gui= is deprecated
# Warning: Option --without-gui= is deprecated
#
# ** (org.inkscape.Inkscape:94742): WARNING **: 17:11:40.787: Ignoring unrecognized CSS property: vertical-align
#
# ** (org.inkscape.Inkscape:94743): WARNING **: 17:11:40.788: Ignoring unrecognized CSS property: vertical-align
#
# ** (org.inkscape.Inkscape:94741): WARNING **: 17:11:40.788: Ignoring unrecognized CSS property: vertical-align
# Background RRGGBBAA: ffffffff
# Area 0:0:6612.7:1080.4 exported to 512 x 64 pixels (7.43297 dpi)
# Background RRGGBBAA: ffffffff
# Area 0:0:10214.9:1223.9 exported to 512 x 64 pixels (4.81179 dpi)
# Background RRGGBBAA: ffffffff
# Area 0:0:14856.4:1726.2 exported to 512 x 64 pixels (3.30847 dpi)
# Warning: Option --without-gui= is deprecated
# Warning: Option --without-gui= is deprecated
#
# ** (org.inkscape.Inkscape:94751): WARNING **: 17:11:41.063: Ignoring unrecognized CSS property: vertical-align
#
# ** (org.inkscape.Inkscape:94753): WARNING **: 17:11:41.064: Ignoring unrecognized CSS property: vertical-align
#
# ** (org.inkscape.Inkscape:94752): WARNING **: 17:11:41.067: Ignoring unrecognized CSS property: vertical-align
# Background RRGGBBAA: ffffffff
# Area 0:0:8426.6:3233.2 exported to 512 x 64 pixels (5.83296 dpi)
# Background RRGGBBAA: ffffffff
# Area 0:0:20248:1367.4 exported to 512 x 64 pixels (2.4275 dpi)
# Background RRGGBBAA: ffffffff
# Area 0:0:31782.5:3233.2 exported to 512 x 64 pixels (1.54651 dpi)
# Warning: Option --without-gui= is deprecatedWarning: Option --without-gui= is deprecated
#
# Warning: Option --without-gui= is deprecated
#
# ** (org.inkscape.Inkscape:94756): WARNING **: 17:11:41.236: Ignoring unrecognized CSS property: vertical-align
#
# ** (org.inkscape.Inkscape:94757): WARNING **: 17:11:41.236: Ignoring unrecognized CSS property: vertical-align
# Background RRGGBBAA: ffffffff
# Area 0:0:6605.1:3017.9 exported to 512 x 64 pixels (7.44152 dpi)
# Background RRGGBBAA: ffffffff
# Area 0:0:18398.1:2659.1 exported to 512 x 64 pixels (2.67158 dpi)
# Warning: Option --without-gui= is deprecated
# Warning: Option --without-gui= is deprecated
#
# ** (org.inkscape.Inkscape:94761): WARNING **: 17:11:41.512: Ignoring unrecognized CSS property: vertical-align
#
# ** (org.inkscape.Inkscape:94762): WARNING **: 17:11:41.512: Ignoring unrecognized CSS property: vertical-align
#
# ** (org.inkscape.Inkscape:94763): WARNING **: 17:11:41.513: Ignoring unrecognized CSS property: vertical-align
# Background RRGGBBAA: ffffffff
# Area 0:0:21968:2443.8 exported to 512 x 64 pixels (2.23744 dpi)
# Background RRGGBBAA: ffffffff
# Area 0:0:23670.7:2228.5 exported to 512 x 64 pixels (2.07649 dpi)
# Background RRGGBBAA: ffffffff
# Area 0:0:36698.5:2228.5 exported to 512 x 64 pixels (1.33935 dpi)
# Warning: Option --without-gui= is deprecated
# Warning: Option --without-gui= is deprecated
# Warning: Option --without-gui= is deprecated
#
# ** (org.inkscape.Inkscape:94764): WARNING **: 17:11:41.674: Ignoring unrecognized CSS property: vertical-align
# Background RRGGBBAA: ffffffff
# Area 0:0:8032.9:1439.2 exported to 512 x 64 pixels (6.11884 dpi)
#
# ** (org.inkscape.Inkscape:94765): WARNING **: 17:11:41.681: Ignoring unrecognized CSS property: vertical-align
# Background RRGGBBAA: ffffffff
# Area 0:0:15378.9:1367.4 exported to 512 x 64 pixels (3.19607 dpi)
# Warning: Option --without-gui= is deprecatedWarning: Option --without-gui= is deprecated
#
#
# ** (org.inkscape.Inkscape:94768): WARNING **: 17:11:41.946: Ignoring unrecognized CSS property: vertical-align
#
# ** (org.inkscape.Inkscape:94767): WARNING **: 17:11:41.949: Ignoring unrecognized CSS property: vertical-align
#
# ** (org.inkscape.Inkscape:94766): WARNING **: 17:11:41.949: Ignoring unrecognized CSS property: vertical-align
# Background RRGGBBAA: ffffffff
# Area 0:0:7433.4:1439.2 exported to 512 x 64 pixels (6.61232 dpi)
# Background RRGGBBAA: ffffffff
# Area 0:0:20115.9:1654.5 exported to 512 x 64 pixels (2.44344 dpi)
# Background RRGGBBAA: ffffffff
# Area 0:0:10165:1223.9 exported to 512 x 64 pixels (4.83542 dpi)
# Warning: Option --without-gui= is deprecated
# Warning: Option --without-gui= is deprecated
# Warning: Option --without-gui= is deprecated
#
# ** (org.inkscape.Inkscape:94769): WARNING **: 17:11:42.130: Ignoring unrecognized CSS property: vertical-align
# Background RRGGBBAA: ffffffff
# Area 0:0:19022.5:1439.2 exported to 512 x 64 pixels (2.58389 dpi)
#
# ** (org.inkscape.Inkscape:94770): WARNING **: 17:11:42.136: Ignoring unrecognized CSS property: vertical-align
# Background RRGGBBAA: ffffffff
# Area 0:0:22545:2443.8 exported to 512 x 64 pixels (2.18017 dpi)
# Warning: Option --without-gui= is deprecated
# Warning: Option --without-gui= is deprecated
#
# ** (org.inkscape.Inkscape:94774): WARNING **: 17:11:42.408: Ignoring unrecognized CSS property: vertical-align
#
# ** (org.inkscape.Inkscape:94772): WARNING **: 17:11:42.408: Ignoring unrecognized CSS property: vertical-align
#
# ** (org.inkscape.Inkscape:94773): WARNING **: 17:11:42.409: Ignoring unrecognized CSS property: vertical-align
# Background RRGGBBAA: ffffffff
# Area 0:0:9885.6:2802.6 exported to 512 x 64 pixels (4.97208 dpi)
# Background RRGGBBAA: ffffffff
# Area 0:0:19889.3:2443.8 exported to 512 x 64 pixels (2.47128 dpi)
# Background RRGGBBAA: ffffffff
# Area 0:0:24732.6:3233.2 exported to 512 x 64 pixels (1.98734 dpi)
# Warning: Option --without-gui= is deprecated
# Warning: Option --without-gui= is deprecated
# Warning: Option --without-gui= is deprecated
#
# ** (org.inkscape.Inkscape:94776): WARNING **: 17:11:42.572: Ignoring unrecognized CSS property: vertical-align
#
# ** (org.inkscape.Inkscape:94775): WARNING **: 17:11:42.573: Ignoring unrecognized CSS property: vertical-align
# Background RRGGBBAA: ffffffff
# Area 0:0:8185.3:1367.4 exported to 512 x 64 pixels (6.00491 dpi)
# Background RRGGBBAA: ffffffff
# Area 0:0:35982.9:1439.2 exported to 512 x 64 pixels (1.36598 dpi)
# Warning: Option --without-gui= is deprecated
# Warning: Option --without-gui= is deprecated
#
# ** (org.inkscape.Inkscape:94779): WARNING **: 17:11:42.843: Ignoring unrecognized CSS property: vertical-align
# Background RRGGBBAA: ffffffff
# Area 0:0:7636.5:1223.9 exported to 512 x 64 pixels (6.43646 dpi)
#
# ** (org.inkscape.Inkscape:94778): WARNING **: 17:11:42.846: Ignoring unrecognized CSS property: vertical-align
#
# ** (org.inkscape.Inkscape:94777): WARNING **: 17:11:42.846: Ignoring unrecognized CSS property: vertical-align
# Background RRGGBBAA: ffffffff
# Area 0:0:17159.2:2659.1 exported to 512 x 64 pixels (2.86447 dpi)
# Background RRGGBBAA: ffffffff
# Area 0:0:14390.6:2443.8 exported to 512 x 64 pixels (3.41556 dpi)
# Warning: Option --without-gui= is deprecated
# Warning: Option --without-gui= is deprecated
# Warning: Option --without-gui= is deprecated
#
# ** (org.inkscape.Inkscape:94780): WARNING **: 17:11:43.002: Ignoring unrecognized CSS property: vertical-align
#
# ** (org.inkscape.Inkscape:94781): WARNING **: 17:11:43.004: Ignoring unrecognized CSS property: vertical-align
# Background RRGGBBAA: ffffffff
# Area 0:0:7755.3:3089.6 exported to 512 x 64 pixels (6.33786 dpi)
# Background RRGGBBAA: ffffffff
# Area 0:0:17047.7:1223.9 exported to 512 x 64 pixels (2.8832 dpi)
# Warning: Option --without-gui= is deprecated
# Warning: Option --without-gui= is deprecated
#
# ** (org.inkscape.Inkscape:94783): WARNING **: 17:11:43.283: Ignoring unrecognized CSS property: vertical-align
#
# ** (org.inkscape.Inkscape:94784): WARNING **: 17:11:43.284: Ignoring unrecognized CSS property: vertical-align
# Background RRGGBBAA: ffffffff
# Area 0:0:6009.8:2228.5 exported to 512 x 64 pixels (8.17864 dpi)
#
# ** (org.inkscape.Inkscape:94785): WARNING **: 17:11:43.286: Ignoring unrecognized CSS property: vertical-align
# Background RRGGBBAA: ffffffff
# Area 0:0:26550.7:1295.7 exported to 512 x 64 pixels (1.85125 dpi)
# Background RRGGBBAA: ffffffff
# Area 0:0:17989.8:3017.9 exported to 512 x 64 pixels (2.73221 dpi)
#
# ** (org.inkscape.Inkscape:94786): WARNING **: 17:11:43.435: Ignoring unrecognized CSS property: vertical-align
#
# ** (org.inkscape.Inkscape:94787): WARNING **: 17:11:43.435: Ignoring unrecognized CSS property: vertical-align
# Warning: Option --without-gui= is deprecated
# Background RRGGBBAA: ffffffff
# Area 0:0:12585.2:1582.7 exported to 512 x 64 pixels (3.90554 dpi)
# Background RRGGBBAA: ffffffff
# Area 0:0:17878.7:1367.4 exported to 512 x 64 pixels (2.74919 dpi)
# Warning: Option --without-gui= is deprecated
# Warning: Option --without-gui= is deprecated
# Warning: Option --without-gui= is deprecated
# Warning: Option --without-gui= is deprecated
#
# ** (org.inkscape.Inkscape:94790): WARNING **: 17:11:43.741: Ignoring unrecognized CSS property: vertical-align
#
# ** (org.inkscape.Inkscape:94789): WARNING **: 17:11:43.743: Ignoring unrecognized CSS property: vertical-align
#
# ** (org.inkscape.Inkscape:94788): WARNING **: 17:11:43.745: Ignoring unrecognized CSS property: vertical-align
# Background RRGGBBAA: ffffffff
# Area 0:0:4157.9:2587.3 exported to 512 x 64 pixels (11.8214 dpi)
# Background RRGGBBAA: ffffffff
# Area 0:0:12435.8:2515.6 exported to 512 x 64 pixels (3.95246 dpi)
# Background RRGGBBAA: ffffffff
# Area 0:0:10419.6:1295.7 exported to 512 x 64 pixels (4.71726 dpi)
#
# ** (org.inkscape.Inkscape:94791): WARNING **: 17:11:43.858: Ignoring unrecognized CSS property: vertical-align
# Background RRGGBBAA: ffffffff
# Area 0:0:14534.3:1439.2 exported to 512 x 64 pixels (3.38179 dpi)
#
# ** (org.inkscape.Inkscape:94792): WARNING **: 17:11:43.878: Ignoring unrecognized CSS property: vertical-align
# Background RRGGBBAA: ffffffff
# Area 0:0:9042.9:2228.5 exported to 512 x 64 pixels (5.43542 dpi)
# Warning: Option --without-gui= is deprecated
# Warning: Option --without-gui= is deprecated
# Warning: Option --without-gui= is deprecated
# Warning: Option --without-gui= is deprecated
# Warning: Option --without-gui= is deprecated
#
# ** (org.inkscape.Inkscape:94794): WARNING **: 17:11:44.184: Ignoring unrecognized CSS property: vertical-align
#
# ** (org.inkscape.Inkscape:94795): WARNING **: 17:11:44.187: Ignoring unrecognized CSS property: vertical-align
# Background RRGGBBAA: ffffffff
# Area 0:0:11950.2:1367.4 exported to 512 x 64 pixels (4.11307 dpi)
#
# ** (org.inkscape.Inkscape:94793): WARNING **: 17:11:44.189: Ignoring unrecognized CSS property: vertical-align
# Background RRGGBBAA: ffffffff
# Area 0:0:19017.9:2515.6 exported to 512 x 64 pixels (2.58451 dpi)
# Background RRGGBBAA: ffffffff
# Area 0:0:30836.1:3950.7 exported to 512 x 64 pixels (1.59398 dpi)
#
# ** (org.inkscape.Inkscape:94797): WARNING **: 17:11:44.280: Ignoring unrecognized CSS property: vertical-align
#
# ** (org.inkscape.Inkscape:94798): WARNING **: 17:11:44.284: Ignoring unrecognized CSS property: vertical-align
# Background RRGGBBAA: ffffffff
# Area 0:0:23288.6:1582.7 exported to 512 x 64 pixels (2.11056 dpi)
# Background RRGGBBAA: ffffffff
# Area 0:0:20493.3:1080.4 exported to 512 x 64 pixels (2.39844 dpi)
# Warning: Option --without-gui= is deprecated
# Warning: Option --without-gui= is deprecated
# Warning: Option --without-gui= is deprecated
# Warning: Option --without-gui= is deprecatedWarning: Option --without-gui= is deprecated
#
#
# ** (org.inkscape.Inkscape:94800): WARNING **: 17:11:44.619: Ignoring unrecognized CSS property: vertical-align
# Background RRGGBBAA: ffffffff
# Area 0:0:8828.2:
# ** (org.inkscape.Inkscape:94799): WARNING **: 17:11:44.623: Ignoring unrecognized CSS property: vertical-align
# 2228.5 exported to 512 x 64 pixels (5.56761 dpi)
#
# ** (org.inkscape.Inkscape:94801): WARNING **: 17:11:44.626: Ignoring unrecognized CSS property: vertical-align
# Background RRGGBBAA: ffffffff
# Area 0:0:9399.1:1295.7 exported to 512 x 64 pixels (5.22944 dpi)
# Background RRGGBBAA: ffffffff
# Area 0:0:19278.9:2443.8 exported to 512 x 64 pixels (2.54952 dpi)
#
# ** (org.inkscape.Inkscape:94802): WARNING **: 17:11:44.711: Ignoring unrecognized CSS property: vertical-align
#
# ** (org.inkscape.Inkscape:94803): WARNING **: 17:11:44.711: Ignoring unrecognized CSS property: vertical-align
# Background RRGGBBAA: ffffffff
# Area 0:0:12768:1510.9 exported to 512 x 64 pixels (3.84962 dpi)
# Background RRGGBBAA: ffffffff
# Area 0:0:23339.8:2659.1 exported to 512 x 64 pixels (2.10593 dpi)
# Warning: Option --without-gui= is deprecated
# Warning: Option --without-gui= is deprecated
# Warning: Option --without-gui= is deprecated
#
# ** (org.inkscape.Inkscape:94804): WARNING **: 17:11:45.033: Ignoring unrecognized CSS property: margin-left
#
# ** (org.inkscape.Inkscape:94805): WARNING **: 17:11:45.033: Ignoring unrecognized CSS property: vertical-align
#
# ** (org.inkscape.Inkscape:94804): WARNING **: 17:11:45.033: Ignoring unrecognized CSS property: vertical-align
# Background RRGGBBAA: ffffffff
# Area 0:0:11207.1:3161.4 exported to 512 x 64 pixels (4.38579 dpi)
# Background RRGGBBAA: ffffffff
# Area 0:0:14451.6:1223.9 exported to 512 x 64 pixels (3.40115 dpi)
#
# ** (org.inkscape.Inkscape:94806): WARNING **: 17:11:45.111: Ignoring unrecognized CSS property: vertical-align
# Background RRGGBBAA: ffffffff
# Area 0:0:16054.6:1439.2 exported to 512 x 64 pixels (3.06155 dpi)
# Warning: Option --without-gui= is deprecated
# Generated 367 images from formulas
# ** (org.inkscape.Inkscape:94808): WARNING **: 17:11:45.436: Ignoring unrecognized CSS property: vertical-align
# Background RRGGBBAA: ffffffff
# Area 0:0:11317.1:2515.6 exported to 512 x 64 pixels (4.34316 dpi)
