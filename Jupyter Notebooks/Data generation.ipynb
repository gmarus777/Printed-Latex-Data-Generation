# %%
# Here we take care of paths.

from pathlib import Path
import os
print('Starting path:' + os.getcwd())
if os.getcwd()[-29:] == "Printed-Latex-Data-Generation":
    pass
else:
    PATH = Path().resolve().parents[0]
    os.chdir(PATH)

# make sure you are in Paragraph_to_Tex folder
print('Current path:' + os.getcwd())
# Out:
# Starting path:/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/Jupyter Notebooks
# Current path:/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation

# %%
from Printed_Tex import Generate_Printed_Tex

# %%
Generate_Printed_Tex(download_tex_dataset=False,
                    generate_tex_formulas =False,
                     number_tex_formulas_to_generate =1,
                     generate_svg_images_from_tex = False,
                     generate_png_from_svg = True,
                    )
# Out:
# Turning svg into png...
# Warning: Option --without-gui= is deprecatedWarning: Option --without-gui= is deprecated
#
# Warning: Option --without-gui= is deprecated
# Warning: Option --without-gui= is deprecated
# Warning: Option --without-gui= is deprecated
# Warning: Option --without-gui= is deprecated
# Warning: Option --without-gui= is deprecated
# Warning: Option --without-gui= is deprecated
# Warning: Option --without-gui= is deprecated
# Warning: Option --without-gui= is deprecated
# Warning: Option --without-gui= is deprecated
# Warning: Option --without-gui= is deprecated
# Warning: Option --without-gui= is deprecated
# Warning: Option --without-gui= is deprecated
# Warning: Option --without-gui= is deprecated
# Warning: Option --without-gui= is deprecated
# Warning: Option --without-gui= is deprecated
# Warning: Option --without-gui= is deprecated
# Warning: Option --without-gui= is deprecated
# Warning: Option --without-gui= is deprecated
# Warning: Option --without-gui= is deprecated
# Warning: Option --without-gui= is deprecated
# Warning: Option --without-gui= is deprecated
# Warning: Option --without-gui= is deprecated
# Warning: Option --without-gui= is deprecated
# Warning: Option --without-gui= is deprecated
# Warning: Option --without-gui= is deprecated
# Warning: Option --without-gui= is deprecated
# Warning: Option --without-gui= is deprecated
# Warning: Option --without-gui= is deprecated
# Warning: Option --without-gui= is deprecated
# Warning: Option --without-gui= is deprecated
# Warning: Option --without-gui= is deprecated
# Warning: Option --without-gui= is deprecated
# Warning: Option --without-gui= is deprecated
# Warning: Option --without-gui= is deprecated
# Warning: Option --without-gui= is deprecated
# Warning: Option --without-gui= is deprecated
# Warning: Option --without-gui= is deprecated
# Warning: Option --without-gui= is deprecated
# Warning: Option --without-gui= is deprecated
# Warning: Option --without-gui= is deprecated
# Warning: Option --without-gui= is deprecated
# Warning: Option --without-gui= is deprecated
# Warning: Option --without-gui= is deprecated
# Warning: Option --without-gui= is deprecated
# Warning: Option --without-gui= is deprecated
# Warning: Option --without-gui= is deprecated
# Warning: Option --without-gui= is deprecated
# Warning: Option --without-gui= is deprecated
# Warning: Option --without-gui= is deprecated
# Warning: Option --without-gui= is deprecated
# Warning: Option --without-gui= is deprecated
# Warning: Option --without-gui= is deprecated
# Warning: Option --without-gui= is deprecated
# Warning: Option --without-gui= is deprecated
# Warning: Option --without-gui= is deprecated
# Warning: Option --without-gui= is deprecated
# Warning: Option --without-gui= is deprecated
# Warning: Option --without-gui= is deprecated
# Warning: Option --without-gui= is deprecated
# Warning: Option --without-gui= is deprecated
# Warning: Option --without-gui= is deprecated
# Warning: Option --without-gui= is deprecated
#
# ** (org.inkscape.Inkscape:76872): WARNING **: 14:07:44.567: Ignoring unrecognized CSS property: vertical-align
#
# ** (org.inkscape.Inkscape:76826): WARNING **: 14:07:44.567: Ignoring unrecognized CSS property: vertical-align
#
# ** (org.inkscape.Inkscape:76837): WARNING **: 14:07:44.567: Ignoring unrecognized CSS property: vertical-align
#
# ** (org.inkscape.Inkscape:76858): WARNING **: 14:07:44.567: Ignoring unrecognized CSS property: margin-left
#
# ** (org.inkscape.Inkscape:76858): WARNING **: 14:07:44.567: Ignoring unrecognized CSS property: vertical-align
#
# ** (org.inkscape.Inkscape:76821): WARNING **: 14:07:44.567: Ignoring unrecognized CSS property: vertical-align
#
# ** (org.inkscape.Inkscape:76865): WARNING **: 14:07:44.567: Ignoring unrecognized CSS property: vertical-align
#
# ** (org.inkscape.Inkscape:76818): WARNING **: 14:07:44.567: Ignoring unrecognized CSS property: margin-bottom
#
# ** (org.inkscape.Inkscape:76818): WARNING **: 14:07:44.567: Ignoring unrecognized CSS property: vertical-align
# Background RRGGBBAA: ffffffff
# Area 0:0:21619:2443.8 exported to 512 x 64 pixels (2.27356 dpi)
# Background RRGGBBAA: ffffffff
# Area 0:0Background RRGGBBAA: :16370.3:ffffffff1367.4
#  exported to Area 512 x 640 pixels (:3.002510:6853:1295.7 exported to 512 x 64 pixels (7.17233 dpi)
# Background RRGGBBAA: ffffffff
# Area 0:0:33036.7:1367.4 exported to 512 x 64 pixels (1.4878 dpi)
#  dpi)
# Background RRGGBBAA: ffffffff
# Area 0:0:28392.4:2659.1 exported to 512 x 64 pixels (1.73117 dpi)
# Background RRGGBBAA: ffffffff
# Area 0:0:23051.9:2946.1 exported to 512 x 64 pixels (2.13223 dpi)
# Background RRGGBBAA: ffffffff
# Area 0:0:18523:1367.4 exported to 512 x 64 pixels (2.65357 dpi)
#
# ** (org.inkscape.Inkscape:76829): WARNING **: 14:07:44.642: Ignoring unrecognized CSS property: vertical-align
#
# ** (org.inkscape.Inkscape:76827): WARNING **: 14:07:44.656: Ignoring unrecognized CSS property: vertical-align
# Background RRGGBBAA: ffffffff
# Area 0:0:17499:1367.4 exported to 512 x 64 pixels (2.80885 dpi)
#
# ** (org.inkscape.Inkscape:76859): WARNING **: 14:07:44.670: Ignoring unrecognized CSS property: vertical-align
#
# ** (org.inkscape.Inkscape:76869): WARNING **: 14:07:44.675: Ignoring unrecognized CSS property: vertical-align
# Background RRGGBBAA: ffffffff
# Area 0:0:15411.6:2659.1 exported to 512 x 64 pixels (3.18929 dpi)
# Background RRGGBBAA: ffffffff
# Area 0:0:7615.1:2300.3 exported to 512 x 64 pixels (6.45454 dpi)
#
# ** (org.inkscape.Inkscape:76868): WARNING **: 14:07:44.691: Ignoring unrecognized CSS property: vertical-align
#
# ** (org.inkscape.Inkscape:76871): WARNING **: 14:07:44.691: Ignoring unrecognized CSS property: vertical-align
#
# ** (org.inkscape.Inkscape:76838): WARNING **: 14:07:44.691: Ignoring unrecognized CSS property: vertical-align
#
# ** (org.inkscape.Inkscape:76878): WARNING **: 14:07:44.695: Ignoring unrecognized CSS property: vertical-align
# Background RRGGBBAA: ffffffff
# Area 0:0:11549.3:2228.5 exported to 512 x 64 pixels (4.25584 dpi)
# Background RRGGBBAA: ffffffff
# Area 0:0:15916.2:2587.3 exported to 512 x 64 pixels (3.08817 dpi)
# Background RRGGBBAA: ffffffff
# Area 0:0:10355.1:3161.4 exported to 512 x 64 pixels (4.74665 dpi)
# Background RRGGBBAA: ffffffff
# Area 0:0:26181.7:2443.8 exported to 512 x 64 pixels (1.87734 dpi)
# Background RRGGBBAA: ffffffff
# Area 0:0:22866.2:9978.5 exported to 512 x 64 pixels (2.14955 dpi)
#
# ** (org.inkscape.Inkscape:76862): WARNING **: 14:07:44.749: Ignoring unrecognized CSS property: vertical-align
#
# ** (org.inkscape.Inkscape:76864): WARNING **: 14:07:44.749: Ignoring unrecognized CSS property: vertical-align
# Background RRGGBBAA: ffffffff
# Area 0:0:27071.2:2443.8 exported to 512 x 64 pixels (1.81566 dpi)
# Background RRGGBBAA: ffffffff
# Area 0:0:25998.9:3161.4 exported to 512 x 64 pixels (1.89054 dpi)
#
# ** (org.inkscape.Inkscape:76828): WARNING **: 14:07:44.782: Ignoring unrecognized CSS property: vertical-align
#
# ** (org.inkscape.Inkscape:76819): WARNING **: 14:07:44.786: Ignoring unrecognized CSS property: vertical-align
#
# ** (org.inkscape.Inkscape:76850): WARNING **: 14:07:44.787: Ignoring unrecognized CSS property: vertical-align
#
# ** (org.inkscape.Inkscape:76861): WARNING **: 14:07:44.790: Ignoring unrecognized CSS property: vertical-align
# Background RRGGBBAA: ffffffff
# Area 0:0:7776.2:1295.7 exported to 512 x 64 pixels (6.32082 dpi)
#
# ** (org.inkscape.Inkscape:76848): WARNING **: 14:07:44.792: Ignoring unrecognized CSS property: vertical-align
#
# ** (org.inkscape.Inkscape:76842): WARNING **: 14:07:44.794: Ignoring unrecognized CSS property: vertical-align
# Background RRGGBBAA: ffffffff
# Area 0:0:16454.7:1295.7 exported to 512 x 64 pixels (2.98711 dpi)
# Background RRGGBBAA: ffffffff
# Area 0:0:6949.3:1439.2 exported to 512 x 64 pixels (7.07294 dpi)
# Background RRGGBBAA: ffffffff
# Area 0:0:16812.1:2659.1 exported to 512 x 64 pixels (2.92361 dpi)
#
# ** (org.inkscape.Inkscape:76846): WARNING **: 14:07:44.816: Ignoring unrecognized CSS property: vertical-align
#
# ** (org.inkscape.Inkscape:76876): WARNING **: 14:07:44.819: Ignoring unrecognized CSS property: vertical-align
# Background RRGGBBAA: ffffffff
# Area 0:0:6446.2:2802.6 exported to 512 x 64 pixels (7.62496 dpi)
#
# ** (org.inkscape.Inkscape:76867): WARNING **: 14:07:44.825: Ignoring unrecognized CSS property: vertical-align
# Background RRGGBBAA: ffffffff
# Area 0:0:25395.5:3520.2 exported to 512 x 64 pixels (1.93546 dpi)
# Background RRGGBBAA: ffffffff
# Area 0:0:35282.2:1510.9 exported to 512 x 64 pixels (1.39311 dpi)
# Background RRGGBBAA: ffffffff
# Area 0:0:17267.8:1798 exported to 512 x 64 pixels (2.84645 dpi)
#
# ** (org.inkscape.Inkscape:76823): WARNING **: 14:07:44.839: Ignoring unrecognized CSS property: vertical-align
#
# ** (org.inkscape.Inkscape:76824): WARNING **: 14:07:44.856: Ignoring unrecognized CSS property: vertical-align
# Background RRGGBBAA: ffffffff
# Area 0:0:5466.6:1295.7 exported to 512 x 64 pixels (8.99133 dpi)
#
# ** (org.inkscape.Inkscape:76866): WARNING **: 14:07:44.860: Ignoring unrecognized CSS property: vertical-align
#
# ** (org.inkscape.Inkscape:76817): WARNING **: 14:07:44.870: Ignoring unrecognized CSS property: vertical-align
# Background RRGGBBAA: ffffffff
# Area 0:0:15408.3:1798 exported to 512 x 64 pixels (3.18997 dpi)
# Background RRGGBBAA: ffffffff
# Area 0:0:9161.6:1510.9 exported to 512 x 64 pixels (5.365 dpi)
#
# ** (org.inkscape.Inkscape:76836): WARNING **: 14:07:44.878: Ignoring unrecognized CSS property: vertical-align
# Background RRGGBBAA: ffffffff
# Area 0:0:17034.6:2515.6 exported to 512 x 64 pixels (2.88542 dpi)
#
# ** (org.inkscape.Inkscape:76843): WARNING **: 14:07:44.893: Ignoring unrecognized CSS property: vertical-align
#
# ** (org.inkscape.Inkscape:76863): WARNING **: 14:07:44.896: Ignoring unrecognized CSS property: vertical-align
#
# ** (org.inkscape.Inkscape:76857): WARNING **: 14:07:44.899: Ignoring unrecognized CSS property: vertical-align
# Background RRGGBBAA: ffffffff
# Area 0:0:6291.4:1367.4 exported to 512 x 64 pixels (7.81257 dpi)
# Background RRGGBBAA: ffffffff
# Area 0:0:15976.3:2443.8 exported to 512 x 64 pixels (3.07656 dpi)
#
# ** (org.inkscape.Inkscape:76835): WARNING **: 14:07:44.905: Ignoring unrecognized CSS property: vertical-align
# Background RRGGBBAA: ffffffff
# Area 0:0:
# ** (org.inkscape.Inkscape:76847): WARNING **: 14:07:44.908: Ignoring unrecognized CSS property: vertical-align
# 13817:1654.5 exported to 512 x 64 pixels (3.55736 dpi)
# Background RRGGBBAA: ffffffff
# Area 0:0:17543.8:2802.6 exported to 512 x 64 pixels (2.80167 dpi)
# Background RRGGBBAA: ffffffff
# Area 0:0:13012.7:1223.9 exported to 512 x 64 pixels (3.77723 dpi)
#
# ** (org.inkscape.Inkscape:76831): WARNING **: 14:07:44.915: Ignoring unrecognized CSS property: vertical-align
# Background RRGGBBAA: ffffffff
# Area 0:0:24927.6:3233.2 exported to 512 x 64 pixels (1.97179 dpi)
#
# ** (org.inkscape.Inkscape:76873): WARNING **: 14:07:44.925: Ignoring unrecognized CSS property: vertical-align
# Background RRGGBBAA: ffffffff
# Area 0:0:35007.1:1869.7 exported to 512 x 64 pixels (1.40406 dpi)
#
# ** (org.inkscape.Inkscape:76877): WARNING **: 14:07:44.926: Ignoring unrecognized CSS property: vertical-align
#
# ** (org.inkscape.Inkscape:76879): WARNING **: 14:07:44.928: Ignoring unrecognized CSS property: vertical-align
# Background RRGGBBAA: ffffffff
# Area 0:0:8211.8:1510.9 exported to 512 x 64 pixels (5.98553 dpi)
# Background RRGGBBAA: ffffffff
# Area 0:0:6398.8:2515.6 exported to 512 x 64 pixels (7.68144 dpi)
# Background RRGGBBAA: ffffffff
# Area 0:0:13551.8:1295.7 exported to 512 x 64 pixels (3.62697 dpi)
# Background RRGGBBAA: ffffffff
# Area 0:0:25233.3:3017.9 exported to 512 x 64 pixels (1.9479 dpi)
#
# ** (org.inkscape.Inkscape:76834): WARNING **: 14:07:44.939: Ignoring unrecognized CSS property: vertical-align
#
# ** (org.inkscape.Inkscape:76880): WARNING **: 14:07:44.944: Ignoring unrecognized CSS property: vertical-align
# Background RRGGBBAA: ffffffff
# Area 0:0:13865:1295.7 exported to 512 x 64 pixels (3.54504 dpi)
# Background RRGGBBAA: ffffffff
# Area 0:0:8439.9:2372 exported to 512 x 64 pixels (5.82377 dpi)
#
# ** (org.inkscape.Inkscape:76832): WARNING **: 14:07:44.950: Ignoring unrecognized CSS property: vertical-align
#
# ** (org.inkscape.Inkscape:76840): WARNING **: 14:07:44.961: Ignoring unrecognized CSS property: vertical-align
#
# ** (org.inkscape.Inkscape:76849): WARNING **: 14:07:44.963: Ignoring unrecognized CSS property: vertical-align
# Background RRGGBBAA: ffffffff
# Area 0:0:6775.9:1295.7 exported to 512 x 64 pixels (7.25394 dpi)
# Background RRGGBBAA: ffffffff
# Area 0:0:31706.7:3233.2 exported to 512 x 64 pixels (1.55021 dpi)
# Background RRGGBBAA: ffffffff
# Area 0:0:11390:1439.2 exported to 512 x 64 pixels (4.31536 dpi)
#
# ** (org.inkscape.Inkscape:76875): WARNING **: 14:07:44.984: Ignoring unrecognized CSS property: vertical-align
#
# ** (org.inkscape.Inkscape:76852): WARNING **: 14:07:44.986: Ignoring unrecognized CSS property: vertical-align
#
# ** (org.inkscape.Inkscape:76855): WARNING **: 14:07:44.993: Ignoring unrecognized CSS property: vertical-align
# Background RRGGBBAA: ffffffff
# Area 0:0:16884.6:1439.2 exported to 512 x 64 pixels (2.91106 dpi)
#
# ** (org.inkscape.Inkscape:76841): WARNING **: 14:07:45.024: Ignoring unrecognized CSS property: vertical-align
# Background RRGGBBAA: ffffffff
# Area 0:0:30841.3:3233.2 exported to 512 x 64 pixels (1.59371 dpi)
#
# ** (org.inkscape.Inkscape:76825): WARNING **: 14:07:45.027: Ignoring unrecognized CSS property: vertical-align
# Background RRGGBBAA: ffffffff
# Area 0:0:13640.4:2443.8 exported to 512 x 64 pixels (3.60341 dpi)
# Background RRGGBBAA: ffffffff
# Area 0:0:21987.4:2730.8 exported to 512 x 64 pixels (2.23546 dpi)
#
# ** (org.inkscape.Inkscape:76839): WARNING **: 14:07:45.037: Ignoring unrecognized CSS property: vertical-align
# Background RRGGBBAA: ffffffff
# Area 0:0:10651.8:1295.7 exported to 512 x 64 pixels (4.61443 dpi)
#
# ** (org.inkscape.Inkscape:76822): WARNING **: 14:07:45.058: Ignoring unrecognized CSS property: vertical-align
#
# ** (org.inkscape.Inkscape:76830): WARNING **: 14:07:45.058: Ignoring unrecognized CSS property: vertical-align
# Background RRGGBBAA: ffffffff
# Area 0:0:7844.1:1223.9 exported to 512 x 64 pixels (6.26611 dpi)
# Background RRGGBBAA: ffffffff
# Area 0:0:7358.2:1223.9 exported to 512 x 64 pixels (6.67989 dpi)
# Background RRGGBBAA: ffffffff
# Area 0:0:11832.2:1439.2 exported to 512 x 64 pixels (4.15409 dpi)
#
# ** (org.inkscape.Inkscape:76851): WARNING **: 14:07:45.073: Ignoring unrecognized CSS property: vertical-align
#
# ** (org.inkscape.Inkscape:76820): WARNING **: 14:07:45.076: Ignoring unrecognized CSS property: vertical-align
# Background RRGGBBAA: ffffffff
# Area 0:0:5159.4:
# ** (org.inkscape.Inkscape:76860): WARNING **: 14:07:45.078: Ignoring unrecognized CSS property: vertical-align
# 1223.9 exported to 512 x 64 pixels (9.52669 dpi)
# Background RRGGBBAA: ffffffff
# Area 0:0:19927.1:1726.2 exported to 512 x 64 pixels (2.46659 dpi)
#
# ** (org.inkscape.Inkscape:76870): WARNING **: 14:07:45.082: Ignoring unrecognized CSS property: vertical-align
#
# ** (org.inkscape.Inkscape:76833): WARNING **: 14:07:45.085: Ignoring unrecognized CSS property: vertical-align
#
# ** (org.inkscape.Inkscape:76854): WARNING **: 14:07:45.086: Ignoring unrecognized CSS property: vertical-align
# Background RRGGBBAA: ffffffff
# Area 0:0:5402:2228.5 exported to 512 x 64 pixels (9.09885 dpi)
# Background RRGGBBAA: ffffffff
# Area 0:0:21644.5:2802.6 exported to 512 x 64 pixels (2.27088 dpi)
# Background RRGGBBAA: ffffffff
# Area 0:0:20841:3017.9 exported to 512 x 64 pixels (2.35843 dpi)
# Background RRGGBBAA: ffffffff
# Area 0:0:7378.4:1439.2 exported to 512 x 64 pixels (6.66161 dpi)
#
# ** (org.inkscape.Inkscape:76844): WARNING **: 14:07:45.095: Ignoring unrecognized CSS property: vertical-align
#
# ** (org.inkscape.Inkscape:76845): WARNING **: 14:07:45.097: Ignoring unrecognized CSS property: vertical-align
# Background RRGGBBAA: ffffffff
# Area 0:0:7705.2:1223.9 exported to 512 x 64 pixels (6.37907 dpi)
#
# ** (org.inkscape.Inkscape:76853): WARNING **: 14:07:45.099: Ignoring unrecognized CSS property: vertical-align
# Background RRGGBBAA: ffffffff
# Area 0:0:8663.8:1510.9 exported to 512 x 64 pixels (5.67326 dpi)
#
# ** (org.inkscape.Inkscape:76856): WARNING **: 14:07:45.104: Ignoring unrecognized CSS property: vertical-align
# Background RRGGBBAA: ffffffff
# Area 0:0:21974.2:2300.3 exported to 512 x 64 pixels (2.23681 dpi)
#
# ** (org.inkscape.Inkscape:76874): WARNING **: 14:07:45.114: Ignoring unrecognized CSS property: vertical-align
# Background RRGGBBAA: ffffffff
# Area 0:0:17171.5:2946.1 exported to 512 x 64 pixels (2.86242 dpi)
# Background RRGGBBAA: ffffffff
# Area 0:0:28194.5:2874.4 exported to 512 x 64 pixels (1.74332 dpi)
# Generated 64 images from formulas
