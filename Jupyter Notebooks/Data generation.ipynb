# %%
# Here we take care of paths.

from pathlib import Path
import os
print('Starting path:' + os.getcwd())
if os.getcwd()[-29:] == "Printed-Latex-Data-Generation":
    pass
else:
    PATH = Path().resolve().parents[0]
    os.chdir(PATH)

# make sure you are in Paragraph_to_Tex folder
print('Current path:' + os.getcwd())
# Out:
# Starting path:/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/Jupyter Notebooks
# Current path:/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation

# %%
from Printed_Tex import Generate_Printed_Tex

# %%
Generate_Printed_Tex(download_tex_dataset=True,
                    generate_tex_formulas =True,
                     number_tex_formulas_to_generate =1,
                     generate_svg_images_from_tex = True,
                     generate_png_from_svg = True,
                    )
# Out:
# /Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/Data/raw_data/chrome
# Done 1 of 12
# Parsed 47628 formulas
# Saving formulas...
# 2022-12-24 14:49:38,368 root  INFO     Script being executed: /Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/preprocess_formulas.py
# \langle W^R_K \rangle = \hbox\mathrm{ dim}\, R \,\exp\left\{ \sum_{i=1}^\infty\sum_{j=1}^{\hat d_i} \alpha_{ij}^c(K)\,r_{ij}^c(R)\,x^i\right\},
#
# TypeError: Cannot read properties of undefined (reading 'type')
#     at Object.handler (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/src/functions.js:126:14)
#     at Parser.callFunction (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/src/Parser.js:575:28)
#     at Parser.parseFunction (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/src/Parser.js:555:31)
#     at Parser.parseImplicitGroup (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/src/Parser.js:527:21)
#     at Parser.parseAtom (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/src/Parser.js:306:21)
#     at Parser.parseExpression (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/src/Parser.js:151:25)
#     at Parser.parseInput (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/src/Parser.js:118:27)
#     at Parser.parse (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/src/Parser.js:109:22)
#     at parseTree (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/src/parseTree.js:14:19)
#     at Object.generateParseTree [as __parse] (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/katex.js:61:12)
# ########--------
# \begin{array}{lll} I_1=(R_{\alpha\beta\rho\sigma} R^{\alpha\beta\rho\sigma})^2, &I_2=R^{\alpha\beta\rho\sigma}R_{\alpha\beta\rho}^{\phantom{\alpha\beta\rho}\lambda}R^{\mu\nu\omega}_{\ph{\mu\nu\omega}\sigma}R_{\mu\nu\omega\lambda},& I_3=R^{\alpha\beta\rho\sigma}R_{\alpha\beta}^{\ph{\alpha\beta}\lambda\mu}R_{\lambda\mu}^{\ph{\lambda\mu}\nu\omega}R_{\rho\sigma\nu\omega},\\I_4=R^{\alpha\beta\rho\sigma}R_{\alpha\beta}^{\ph{\alpha\beta}\lambda\mu}R_{\rho\lambda}^{\ph{\rho\lambda} \nu\omega}R_{\sigma\mu\nu\omega}, &I_5=R^{\alpha\beta\rho\sigma}R_{\alpha\beta}^{\phantom{\alpha\beta}\lambda\mu}R^{\ph{\mu}\nu\ph{\omega}\omega}_{\rho\ph{\mu}\lambda\ph{\mu}}R_{\sigma\nu\mu\\omega}, & I_6=R^{\alpha\beta\rho\sigma}R_{\alpha\ph{p}\rho}^{\ph{p}\lambda\ph{p}\mu}R_{\lambda\sp\mu}^{\sp \nu\sp \omega}R_{\beta\nu\sigma\omega},\\I_7=R^{\alpha\beta\rho\sigma}R_{\alpha\ph{p}\rho}^{\ph{p}\lambda\ph{p}\mu} R_{\lambda\sp\beta}^{\sp \nu\sp \omega}R_{\mu\nu\sigma\omega}. & &\end{array}
#
# ReferenceError: exit is not defined
#     at parseArray (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/src/environments.js:26:13)
#     at Object.handler (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/src/environments.js:129:11)
#     at Parser.parseImplicitGroup (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/src/Parser.js:452:26)
#     at Parser.parseAtom (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/src/Parser.js:306:21)
#     at Parser.parseExpression (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/src/Parser.js:151:25)
#     at Parser.parseInput (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/src/Parser.js:118:27)
#     at Parser.parse (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/src/Parser.js:109:22)
#     at parseTree (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/src/parseTree.js:14:19)
#     at Object.generateParseTree [as __parse] (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/katex.js:61:12)
#     at Interface.<anonymous> (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/preprocess_latex.js:51:30)
# ########--------
# \bpm c'' & d'' \,     r'' & s'' \epm              \in SL(2,\bf{Z}_N)
#
# ParseError: KaTeX parse error: Expected 'EOF', got '&' at position 10: \bpm c'' &̲ d'' \,     r'
#     at new ParseError (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/src/ParseError.js:29:16)
#     at Parser.expect (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/src/Parser.js:78:15)
#     at Parser.parseInput (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/src/Parser.js:120:10)
#     at Parser.parse (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/src/Parser.js:109:22)
#     at parseTree (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/src/parseTree.js:14:19)
#     at Object.generateParseTree [as __parse] (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/katex.js:61:12)
#     at Interface.<anonymous> (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/preprocess_latex.js:51:30)
#     at Interface.emit (node:events:390:28)
#     at Interface._onLine (node:readline:487:10)
#     at Interface._normalWrite (node:readline:661:12) {
#   position: 10
# }
# ########--------
# \begin{split}&\raisebox{-12ex}{\includegraphics[width=45ex]{mom3.eps}} = {\co}(q\wedge (p_2-p_1) +p_1\wedge p_2)\\&\cdot\l(\frac{1}{q^2+m^2}\r)\l(\frac{1}{(q-p)^2+m^2}\r)\l(\frac{1}{(q-p_1)^2+m^2}\r)G_{n+2}(p_1,p_2,k_1,...,k_2) \quad.\end{split}
#
# ParseError: KaTeX parse error: No such environment: split at position 13: \begin{split}̲&\raisebox{-12
#     at new ParseError (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/src/ParseError.js:29:16)
#     at Parser.parseImplicitGroup (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/src/Parser.js:437:19)
#     at Parser.parseAtom (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/src/Parser.js:306:21)
#     at Parser.parseExpression (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/src/Parser.js:151:25)
#     at Parser.parseInput (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/src/Parser.js:118:27)
#     at Parser.parse (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/src/Parser.js:109:22)
#     at parseTree (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/src/parseTree.js:14:19)
#     at Object.generateParseTree [as __parse] (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/katex.js:61:12)
#     at Interface.<anonymous> (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/preprocess_latex.js:51:30)
#     at Interface.emit (node:events:390:28) {
#   position: 13
# }
# ########--------
# c_{\text{eff}}=\frac{6}{\pi ^{2}}\sum\limits_{a=1}^{\tilde{n}
#
# ParseError: KaTeX parse error: Expected '}', got 'EOF' at position 62: =1}^{\tilde{n} ̲
#     at new ParseError (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/src/ParseError.js:29:16)
#     at Parser.expect (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/src/Parser.js:78:15)
#     at Parser.parseGroup (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/src/Parser.js:725:14)
#     at Parser.handleSupSubscript (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/src/Parser.js:236:22)
#     at Parser.parseAtom (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/src/Parser.js:339:32)
#     at Parser.parseExpression (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/src/Parser.js:151:25)
#     at Parser.parseInput (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/src/Parser.js:118:27)
#     at Parser.parse (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/src/Parser.js:109:22)
#     at parseTree (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/src/parseTree.js:14:19)
#     at Object.generateParseTree [as __parse] (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/katex.js:61:12) {
#   position: 62
# }
# ########--------
# \nonumber\xymatrix{0 \ar[drr]^{d_2} & 0  & 0 \\\Ker\ (z-\zeta)\vert_{H^1(K)}\ar[drr]^{d_2} & \Ker\ rest./\mathrm{ Im}\ (z-\zeta)\vert_{H^1(K)} & H_{\bD}^1(E\vert_{z=\zeta})/\mathrm{ Im}\ rest. \vert_{H^1(K)}\\0 &  0 & H_{\bD}^0\left(E\vert_{z=\zeta}\right) .}
#
# ParseError: KaTeX parse error: Expected '}', got '&' at position 37: ar[drr]^{d_2} &̲ 0  & 0 \\\Ker
#     at new ParseError (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/src/ParseError.js:29:16)
#     at Parser.expect (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/src/Parser.js:78:15)
#     at Parser.parseGroup (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/src/Parser.js:725:14)
#     at Parser.parseFunction (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/src/Parser.js:541:26)
#     at Parser.parseImplicitGroup (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/src/Parser.js:409:21)
#     at Parser.parseAtom (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/src/Parser.js:306:21)
#     at Parser.parseExpression (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/src/Parser.js:151:25)
#     at Parser.parseInput (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/src/Parser.js:118:27)
#     at Parser.parse (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/src/Parser.js:109:22)
#     at parseTree (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/src/parseTree.js:14:19) {
#   position: 37
# }
# ########--------
# \begin{split}\Pi \cdot \IP{\prod_{a=1}^l V(\psi_a, z_a)}_{\eta,R} = & \prod_{m=1}^k (z_1 - u_m)^{h_1} \sum_{i=2}^{l} \sum_{n = - h_1 - h_i}^{-1} \iota_{1,i} (z_1 - z_i)^{n} g_{i,n}(z_2, \dots, z_l) \\-& \prod_{m=1}^k (z_1 - u_m)^{h_1} \sum_{i=2}^{l-1} \sum_{n = - h_1 - h_i}^{-1} \iota_{i,1} (z_1 - z_i)^{n} g_{i,n}(z_2, \dots, z_l) \\+& \prod_{m=1}^k (z_1 - u_m)^{h_1} \sum_{n = 0}^\infty (z_1 - z_l)^n g_{l,n}(z_2, \dots, z_l).\end{split}
#
# ParseError: KaTeX parse error: No such environment: split at position 13: \begin{split}̲\Pi \cdot \IP{
#     at new ParseError (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/src/ParseError.js:29:16)
#     at Parser.parseImplicitGroup (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/src/Parser.js:437:19)
#     at Parser.parseAtom (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/src/Parser.js:306:21)
#     at Parser.parseExpression (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/src/Parser.js:151:25)
#     at Parser.parseInput (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/src/Parser.js:118:27)
#     at Parser.parse (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/src/Parser.js:109:22)
#     at parseTree (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/src/parseTree.js:14:19)
#     at Object.generateParseTree [as __parse] (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/katex.js:61:12)
#     at Interface.<anonymous> (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/preprocess_latex.js:51:30)
#     at Interface.emit (node:events:390:28) {
#   position: 13
# }
# ########--------
# \left\{ \begin{split}(h_l)^\prime_u(\alpha_u) &= -g_l(u) \\(h_l)^{[1+n]}_u (\alpha_u) &=: -(n+1) \:g^{[n]}_l(u) \\(h_l)^\prime_u(\alpha_u) \:\alpha_u - (h_l)_u(\alpha_u) &=:\frac{b(u)}{u} \:g_l(u) \;;\end{split} \right.
#
# ParseError: KaTeX parse error: No such environment: split at position 21: { \begin{split}̲(h_l)^\prime_u
#     at new ParseError (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/src/ParseError.js:29:16)
#     at Parser.parseImplicitGroup (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/src/Parser.js:437:19)
#     at Parser.parseAtom (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/src/Parser.js:306:21)
#     at Parser.parseExpression (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/src/Parser.js:151:25)
#     at Parser.parseImplicitGroup (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/src/Parser.js:419:21)
#     at Parser.parseAtom (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/src/Parser.js:306:21)
#     at Parser.parseExpression (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/src/Parser.js:151:25)
#     at Parser.parseInput (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/src/Parser.js:118:27)
#     at Parser.parse (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/src/Parser.js:109:22)
#     at parseTree (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/src/parseTree.js:14:19) {
#   position: 21
# }
# ########--------
# S_{li}(\theta -i\bar{u}_{ki}^{j})S_{lj}(\theta +i\bar{u}_{jk}^{i})=S_{l\bar{k
#
# ParseError: KaTeX parse error: Expected '}', got 'EOF' at position 78: i})=S_{l\bar{k ̲
#     at new ParseError (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/src/ParseError.js:29:16)
#     at Parser.expect (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/src/Parser.js:78:15)
#     at Parser.parseGroup (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/src/Parser.js:725:14)
#     at Parser.parseArguments (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/src/Parser.js:613:28)
#     at Parser.parseFunction (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/src/Parser.js:554:29)
#     at Parser.parseImplicitGroup (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/src/Parser.js:527:21)
#     at Parser.parseAtom (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/src/Parser.js:306:21)
#     at Parser.parseExpression (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/src/Parser.js:151:25)
#     at Parser.parseGroup (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/src/Parser.js:723:31)
#     at Parser.handleSupSubscript (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/src/Parser.js:236:22) {
#   position: 78
# }
# ########--------
# E_{\text{total}}\equiv E\left( \mathcal{P}_{\left\{ n_{1}+m_{1}\theta_{1},\ldots ,n_{l}+m_{l}\theta _{l}\right\} }\right) =M_{\text{D2}
#
# ParseError: KaTeX parse error: Expected '}', got 'EOF' at position 136:  =M_{\text{D2} ̲
#     at new ParseError (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/src/ParseError.js:29:16)
#     at Parser.expect (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/src/Parser.js:78:15)
#     at Parser.parseGroup (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/src/Parser.js:725:14)
#     at Parser.handleSupSubscript (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/src/Parser.js:236:22)
#     at Parser.parseAtom (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/src/Parser.js:346:30)
#     at Parser.parseExpression (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/src/Parser.js:151:25)
#     at Parser.parseInput (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/src/Parser.js:118:27)
#     at Parser.parse (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/src/Parser.js:109:22)
#     at parseTree (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/src/parseTree.js:14:19)
#     at Object.generateParseTree [as __parse] (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/katex.js:61:12) {
#   position: 136
# }
# ########--------
# M(q,\hat{q})=\sum_{x=1}^{h}\sum_{y=1}^{H}\mu (x,y)\left( q^{x}\hat{q}
#
# ParseError: KaTeX parse error: Expected '\right', got 'EOF' at position 70: ( q^{x}\hat{q} ̲
#     at new ParseError (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/src/ParseError.js:29:16)
#     at Parser.expect (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/src/Parser.js:78:15)
#     at Parser.parseImplicitGroup (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/src/Parser.js:421:14)
#     at Parser.parseAtom (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/src/Parser.js:306:21)
#     at Parser.parseExpression (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/src/Parser.js:151:25)
#     at Parser.parseInput (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/src/Parser.js:118:27)
#     at Parser.parse (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/src/Parser.js:109:22)
#     at parseTree (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/src/parseTree.js:14:19)
#     at Object.generateParseTree [as __parse] (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/katex.js:61:12)
#     at Interface.<anonymous> (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/preprocess_latex.js:51:30) {
#   position: 70
# }
# ########--------
# {\cal O}_{1}=\int_{q}\left[ \frac{\delta ^{2}S}{\delta \phi _{q}\delta \phi_{-q}}-\frac{\delta S}{\delta \phi _{q}}\frac{\delta S}{\delta \phi _{-q}}
#
# ParseError: KaTeX parse error: Expected '\right', got 'EOF' at position 150: ta \phi _{-q}} ̲
#     at new ParseError (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/src/ParseError.js:29:16)
#     at Parser.expect (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/src/Parser.js:78:15)
#     at Parser.parseImplicitGroup (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/src/Parser.js:421:14)
#     at Parser.parseAtom (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/src/Parser.js:306:21)
#     at Parser.parseExpression (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/src/Parser.js:151:25)
#     at Parser.parseInput (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/src/Parser.js:118:27)
#     at Parser.parse (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/src/Parser.js:109:22)
#     at parseTree (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/src/parseTree.js:14:19)
#     at Object.generateParseTree [as __parse] (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/katex.js:61:12)
#     at Interface.<anonymous> (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/preprocess_latex.js:51:30) {
#   position: 150
# }
# ########--------
# \left.   \begin{gathered}     \com{\hat{b}^+}{\hat{b}^-}=i, \\     \com{\hat{b}^+}{\hat{b}^+}=0,\,\,\,\com{\hat{b}^-}{\hat{b}^-}=0.    \end{gathered} \right\}
#
# ParseError: KaTeX parse error: No such environment: gathered at position 25: begin{gathered}̲     \com{\hat
#     at new ParseError (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/src/ParseError.js:29:16)
#     at Parser.parseImplicitGroup (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/src/Parser.js:437:19)
#     at Parser.parseAtom (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/src/Parser.js:306:21)
#     at Parser.parseExpression (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/src/Parser.js:151:25)
#     at Parser.parseImplicitGroup (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/src/Parser.js:419:21)
#     at Parser.parseAtom (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/src/Parser.js:306:21)
#     at Parser.parseExpression (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/src/Parser.js:151:25)
#     at Parser.parseInput (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/src/Parser.js:118:27)
#     at Parser.parse (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/src/Parser.js:109:22)
#     at parseTree (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/src/parseTree.js:14:19) {
#   position: 25
# }
# ########--------
# \begin{split}O_\uu = \Span \ \Big\{ \ci_0 dz \, g(z) V(\psi, z) \chi \ \Big\vert\        &\chi \in \HH, \psi \in V,\, \hbox{ g  meromorphic}, \\        & \Div g dz^{\otimes -h_\psi+1} \ge -N[0] + \sum_{i=1}^k h_\psi       [u_i] \textrm{    for some } N\geq 0\Big\}\,. \end{split}
#
# ParseError: KaTeX parse error: No such environment: split at position 13: \begin{split}̲O_\uu = \Span
#     at new ParseError (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/src/ParseError.js:29:16)
#     at Parser.parseImplicitGroup (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/src/Parser.js:437:19)
#     at Parser.parseAtom (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/src/Parser.js:306:21)
#     at Parser.parseExpression (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/src/Parser.js:151:25)
#     at Parser.parseInput (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/src/Parser.js:118:27)
#     at Parser.parse (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/src/Parser.js:109:22)
#     at parseTree (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/src/parseTree.js:14:19)
#     at Object.generateParseTree [as __parse] (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/katex.js:61:12)
#     at Interface.<anonymous> (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/preprocess_latex.js:51:30)
#     at Interface.emit (node:events:390:28) {
#   position: 13
# }
# ########--------
# e = e^* \, , \ e^2 = e \, , \ \left\lgl e - \frac{1}{2} \right\rgl = 0
#
# ParseError: KaTeX parse error: Invalid delimiter: '\lgl' after '\left' at position 39: , , \ \left\lgl̲ e - \frac{1}{
#     at new ParseError (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/src/ParseError.js:29:16)
#     at Object.handler (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/src/functions.js:447:15)
#     at Parser.callFunction (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/src/Parser.js:575:28)
#     at Parser.parseFunction (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/src/Parser.js:555:31)
#     at Parser.parseImplicitGroup (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/src/Parser.js:417:25)
#     at Parser.parseAtom (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/src/Parser.js:306:21)
#     at Parser.parseExpression (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/src/Parser.js:151:25)
#     at Parser.parseInput (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/src/Parser.js:118:27)
#     at Parser.parse (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/src/Parser.js:109:22)
#     at parseTree (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/src/parseTree.js:14:19) {
#   position: 39
# }
# ########--------
# \def\mapright#1{\smash{\mathop{\longrightarrow}\limits^{#1}}}(a_i,b_j)~~\mapright{f} ~~(n_i\alpha+r_i\beta,m_j\alpha+s_j\beta)
#
# ParseError: KaTeX parse error: Limit controls must follow a math operator at position 47: longrightarrow}̲\limits^{#1}}}
#     at new ParseError (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/src/ParseError.js:29:16)
#     at Parser.parseAtom (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/src/Parser.js:324:23)
#     at Parser.parseExpression (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/src/Parser.js:151:25)
#     at Parser.parseGroup (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/src/Parser.js:723:31)
#     at Parser.parseFunction (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/src/Parser.js:541:26)
#     at Parser.parseImplicitGroup (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/src/Parser.js:409:21)
#     at Parser.parseAtom (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/src/Parser.js:306:21)
#     at Parser.parseExpression (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/src/Parser.js:151:25)
#     at Parser.parseGroup (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/src/Parser.js:723:31)
#     at Parser.parseFunction (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/src/Parser.js:541:26) {
#   position: 47
# }
# ########--------
# \begin{split}  &\dd^{y}_{\mu}\TT{W_{1}(x_1), \dots ,W_{n}(x_n), k^{\mu}(y)} = \\  &\qquad = \sum_{k=1}^n \delta(y-x_k) \, g(W_k)\,  \TT{W_{1}(x_1), \dots ,W_{n}(x_n)} \end{split}
#
# ParseError: KaTeX parse error: No such environment: split at position 13: \begin{split}̲  &\dd^{y}_{\m
#     at new ParseError (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/src/ParseError.js:29:16)
#     at Parser.parseImplicitGroup (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/src/Parser.js:437:19)
#     at Parser.parseAtom (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/src/Parser.js:306:21)
#     at Parser.parseExpression (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/src/Parser.js:151:25)
#     at Parser.parseInput (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/src/Parser.js:118:27)
#     at Parser.parse (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/src/Parser.js:109:22)
#     at parseTree (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/src/parseTree.js:14:19)
#     at Object.generateParseTree [as __parse] (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/katex.js:61:12)
#     at Interface.<anonymous> (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/preprocess_latex.js:51:30)
#     at Interface.emit (node:events:390:28) {
#   position: 13
# }
# ########--------
# T_{\mu \nu }=\left( P_{\mu }\varphi \right) ^{\ast }P_{\nu }\varphi +\left(P_{\nu }\varphi \right) ^{\ast }P_{\mu }\varphi -\frac{g_{\mu \nu }}{\sqrt{-g
#
# ParseError: KaTeX parse error: Expected '}', got 'EOF' at position 153: nu }}{\sqrt{-g ̲
#     at new ParseError (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/src/ParseError.js:29:16)
#     at Parser.expect (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/src/Parser.js:78:15)
#     at Parser.parseGroup (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/src/Parser.js:725:14)
#     at Parser.parseArguments (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/src/Parser.js:613:28)
#     at Parser.parseFunction (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/src/Parser.js:554:29)
#     at Parser.parseImplicitGroup (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/src/Parser.js:527:21)
#     at Parser.parseAtom (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/src/Parser.js:306:21)
#     at Parser.parseExpression (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/src/Parser.js:151:25)
#     at Parser.parseGroup (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/src/Parser.js:723:31)
#     at Parser.parseArguments (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/src/Parser.js:613:28) {
#   position: 153
# }
# ########--------
# K(\bo{\hat{E}}_N)=\left(\ba1& 9-N\,0& 1\ea\right).
#
# ParseError: KaTeX parse error: Expected '\right', got '&' at position 29: _N)=\left(\ba1&̲ 9-N\,0& 1\ea\
#     at new ParseError (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/src/ParseError.js:29:16)
#     at Parser.expect (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/src/Parser.js:78:15)
#     at Parser.parseImplicitGroup (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/src/Parser.js:421:14)
#     at Parser.parseAtom (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/src/Parser.js:306:21)
#     at Parser.parseExpression (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/src/Parser.js:151:25)
#     at Parser.parseInput (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/src/Parser.js:118:27)
#     at Parser.parse (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/src/Parser.js:109:22)
#     at parseTree (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/src/parseTree.js:14:19)
#     at Object.generateParseTree [as __parse] (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/katex.js:61:12)
#     at Interface.<anonymous> (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/preprocess_latex.js:51:30) {
#   position: 29
# }
# ########--------
# J_\mu ^{\mathrm{ reg}}=\left. -\frac{d~}{d\lambda }\left\{ \lambda \mathrm{ Tr}
#
# ParseError: KaTeX parse error: Expected '\right', got 'EOF' at position 80: a \mathrm{ Tr} ̲
#     at new ParseError (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/src/ParseError.js:29:16)
#     at Parser.expect (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/src/Parser.js:78:15)
#     at Parser.parseImplicitGroup (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/src/Parser.js:421:14)
#     at Parser.parseAtom (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/src/Parser.js:306:21)
#     at Parser.parseExpression (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/src/Parser.js:151:25)
#     at Parser.parseImplicitGroup (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/src/Parser.js:419:21)
#     at Parser.parseAtom (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/src/Parser.js:306:21)
#     at Parser.parseExpression (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/src/Parser.js:151:25)
#     at Parser.parseInput (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/src/Parser.js:118:27)
#     at Parser.parse (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/src/Parser.js:109:22) {
#   position: 80
# }
# ########--------
# \begin{array}{lllc}\zeta _{\Lambda }(\sigma ) & = & \displaystyle{\frac{1}{2\pi i}}
#
# ParseError: KaTeX parse error: Expected & or \\ or \end at position 84: ac{1}{2\pi i}} ̲
#     at new ParseError (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/src/ParseError.js:29:16)
#     at parseArray (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/src/environments.js:43:19)
#     at Object.handler (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/src/environments.js:129:11)
#     at Parser.parseImplicitGroup (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/src/Parser.js:452:26)
#     at Parser.parseAtom (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/src/Parser.js:306:21)
#     at Parser.parseExpression (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/src/Parser.js:151:25)
#     at Parser.parseInput (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/src/Parser.js:118:27)
#     at Parser.parse (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/src/Parser.js:109:22)
#     at parseTree (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/src/parseTree.js:14:19)
#     at Object.generateParseTree [as __parse] (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/katex.js:61:12) {
#   position: 84
# }
# ########--------
# }
#
# ParseError: KaTeX parse error: Expected 'EOF', got '}' at position 1: }̲
#     at new ParseError (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/src/ParseError.js:29:16)
#     at Parser.expect (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/src/Parser.js:78:15)
#     at Parser.parseInput (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/src/Parser.js:120:10)
#     at Parser.parse (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/src/Parser.js:109:22)
#     at parseTree (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/src/parseTree.js:14:19)
#     at Object.generateParseTree [as __parse] (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/katex.js:61:12)
#     at Interface.<anonymous> (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/preprocess_latex.js:51:30)
#     at Interface.emit (node:events:390:28)
#     at Interface._onLine (node:readline:487:10)
#     at Interface._normalWrite (node:readline:661:12) {
#   position: 1
# }
# ########--------
# \begin{split}O_\uu = \Span \ \Big\{ \ci_0 dz g(z) V(\psi, z) \chi \ \Big\vert \ &\chi \in \F, \psi \in V, \\                    & \Div g dz^{\otimes -h_\psi+1} \ge -N[0] + \sum_{i=1}^k h_\psi [u_i] \textrm{    for some } N\Big\}.\end{split}
#
# ParseError: KaTeX parse error: No such environment: split at position 13: \begin{split}̲O_\uu = \Span
#     at new ParseError (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/src/ParseError.js:29:16)
#     at Parser.parseImplicitGroup (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/src/Parser.js:437:19)
#     at Parser.parseAtom (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/src/Parser.js:306:21)
#     at Parser.parseExpression (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/src/Parser.js:151:25)
#     at Parser.parseInput (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/src/Parser.js:118:27)
#     at Parser.parse (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/src/Parser.js:109:22)
#     at parseTree (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/src/parseTree.js:14:19)
#     at Object.generateParseTree [as __parse] (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/katex.js:61:12)
#     at Interface.<anonymous> (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/preprocess_latex.js:51:30)
#     at Interface.emit (node:events:390:28) {
#   position: 13
# }
# ########--------
# \left( \Phi (p),\Psi (q)\right) =\left\{ \begin{array}{c}0 \\ \Phi ^{\dagger }(p)W(p)\Psi (q)
#
# ParseError: KaTeX parse error: Expected & or \\ or \end at position 94: p)W(p)\Psi (q) ̲
#     at new ParseError (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/src/ParseError.js:29:16)
#     at parseArray (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/src/environments.js:43:19)
#     at Object.handler (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/src/environments.js:129:11)
#     at Parser.parseImplicitGroup (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/src/Parser.js:452:26)
#     at Parser.parseAtom (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/src/Parser.js:306:21)
#     at Parser.parseExpression (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/src/Parser.js:151:25)
#     at Parser.parseImplicitGroup (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/src/Parser.js:419:21)
#     at Parser.parseAtom (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/src/Parser.js:306:21)
#     at Parser.parseExpression (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/src/Parser.js:151:25)
#     at Parser.parseInput (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/src/Parser.js:118:27) {
#   position: 94
# }
# ########--------
# \varepsilon _{c}^{(2)}={\frac{b_{1}+b_{2}}{2^{D}\pi ^{D/2}a^{D+1}\Gamma\left( 1+{\frac{D}{2}}\right) }}\,\mathrm{ p.v.}\int_{0}^{\infty }dt\,{\frac{
#
# ParseError: KaTeX parse error: Expected '}', got 'EOF' at position 149: y }dt\,{\frac{ ̲
#     at new ParseError (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/src/ParseError.js:29:16)
#     at Parser.expect (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/src/Parser.js:78:15)
#     at Parser.parseGroup (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/src/Parser.js:725:14)
#     at Parser.parseArguments (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/src/Parser.js:613:28)
#     at Parser.parseFunction (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/src/Parser.js:554:29)
#     at Parser.parseImplicitGroup (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/src/Parser.js:527:21)
#     at Parser.parseAtom (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/src/Parser.js:306:21)
#     at Parser.parseExpression (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/src/Parser.js:151:25)
#     at Parser.parseGroup (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/src/Parser.js:723:31)
#     at Parser.parseFunction (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/src/Parser.js:541:26) {
#   position: 149
# }
# ########--------
# F_{\mathrm{ ext}}=-p|_{r=a+}=\frac{1}{2\pia^{D+1}S_{D}}\sum_{l=0}^{\infty}D_{l}\int_{ma}^{\infty }\frac{z^{3}dz}{\sqrt{z^{2}-m^{2}a^{2}}}\frac{\bar{I}
#
# ParseError: KaTeX parse error: Expected '}', got 'EOF' at position 151: }\frac{\bar{I} ̲
#     at new ParseError (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/src/ParseError.js:29:16)
#     at Parser.expect (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/src/Parser.js:78:15)
#     at Parser.parseGroup (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/src/Parser.js:725:14)
#     at Parser.parseArguments (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/src/Parser.js:613:28)
#     at Parser.parseFunction (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/src/Parser.js:554:29)
#     at Parser.parseImplicitGroup (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/src/Parser.js:527:21)
#     at Parser.parseAtom (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/src/Parser.js:306:21)
#     at Parser.parseExpression (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/src/Parser.js:151:25)
#     at Parser.parseInput (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/src/Parser.js:118:27)
#     at Parser.parse (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/src/Parser.js:109:22) {
#   position: 151
# }
# ########--------
# e^{-S_{\mathrm{ eff}}[\eta_\mu ]}=\int D\phi D\phi ^{\dagger }e^{-\int d^3x{\cal L}
#
# ParseError: KaTeX parse error: Expected '}', got 'EOF' at position 84: t d^3x{\cal L} ̲
#     at new ParseError (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/src/ParseError.js:29:16)
#     at Parser.expect (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/src/Parser.js:78:15)
#     at Parser.parseGroup (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/src/Parser.js:725:14)
#     at Parser.handleSupSubscript (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/src/Parser.js:236:22)
#     at Parser.parseAtom (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/src/Parser.js:339:32)
#     at Parser.parseExpression (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/src/Parser.js:151:25)
#     at Parser.parseInput (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/src/Parser.js:118:27)
#     at Parser.parse (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/src/Parser.js:109:22)
#     at parseTree (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/src/parseTree.js:14:19)
#     at Object.generateParseTree [as __parse] (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/katex.js:61:12) {
#   position: 84
# }
# ########--------
# W_\gamma^R (A) =\tr_R \big( {\hbox\mathrm{ Hol}}_\gamma (A) \big) =\tr_R {\hbox\mathrm{ P}} \exp \int_\gamma A.
#
# TypeError: Cannot read properties of undefined (reading 'type')
#     at Object.handler (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/src/functions.js:126:14)
#     at Parser.callFunction (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/src/Parser.js:575:28)
#     at Parser.parseFunction (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/src/Parser.js:555:31)
#     at Parser.parseImplicitGroup (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/src/Parser.js:527:21)
#     at Parser.parseAtom (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/src/Parser.js:306:21)
#     at Parser.parseExpression (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/src/Parser.js:151:25)
#     at Parser.parseGroup (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/src/Parser.js:723:31)
#     at Parser.parseFunction (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/src/Parser.js:541:26)
#     at Parser.parseImplicitGroup (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/src/Parser.js:409:21)
#     at Parser.parseAtom (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/src/Parser.js:306:21)
# ########--------
# \left( 2n+1\right) ^{3}\cos \left[ \left( 2n+1\right) \xi \right] =-\frac{
#
# ParseError: KaTeX parse error: Expected '}', got 'EOF' at position 75: ight] =-\frac{ ̲
#     at new ParseError (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/src/ParseError.js:29:16)
#     at Parser.expect (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/src/Parser.js:78:15)
#     at Parser.parseGroup (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/src/Parser.js:725:14)
#     at Parser.parseArguments (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/src/Parser.js:613:28)
#     at Parser.parseFunction (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/src/Parser.js:554:29)
#     at Parser.parseImplicitGroup (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/src/Parser.js:527:21)
#     at Parser.parseAtom (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/src/Parser.js:306:21)
#     at Parser.parseExpression (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/src/Parser.js:151:25)
#     at Parser.parseInput (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/src/Parser.js:118:27)
#     at Parser.parse (/Users/gregory/PROJECT_ML/PROJECT_AMINE/Printed-Latex-Data-Generation/third_party/katex/src/Parser.js:109:22) {
#   position: 75
# }
# ########--------
# M(q,\hat{q})=\frac{1-q^{2h}\hat{q}^{2H}}{2}\,A(q,\hat{q})^{-1}[D]_{\hat{q}
#
# ParseError: KaTeX parse error: Expected '}', got 'EOF' at position 75: 1}[D]_{\hat{q} ̲
# ...
# Warning: Option --without-gui= is deprecated
# Warning: Option --without-gui= is deprecated
# Warning: Option --without-gui= is deprecated
# Warning: Option --without-gui= is deprecated
# Warning: Option --without-gui= is deprecated
# Warning: Option --without-gui= is deprecated
# Warning: Option --without-gui= is deprecated
# Warning: Option --without-gui= is deprecated
# Warning: Option --without-gui= is deprecated
# Warning: Option --without-gui= is deprecated
# Warning: Option --without-gui= is deprecated
# Warning: Option --without-gui= is deprecated
# Warning: Option --without-gui= is deprecated
# Warning: Option --without-gui= is deprecated
# Warning: Option --without-gui= is deprecated
# Warning: Option --without-gui= is deprecated
# Warning: Option --without-gui= is deprecated
# Warning: Option --without-gui= is deprecated
# Warning: Option --without-gui= is deprecated
# Warning: Option --without-gui= is deprecated
# Warning: Option --without-gui= is deprecated
# Warning: Option --without-gui= is deprecated
# Warning: Option --without-gui= is deprecated
#
# ** (org.inkscape.Inkscape:77825): WARNING **: 14:50:20.686: Ignoring unrecognized CSS property: vertical-align
#
# ** (org.inkscape.Inkscape:77803): WARNING **: 14:50:20.686: Ignoring unrecognized CSS property: vertical-align
#
# ** (org.inkscape.Inkscape:77800): WARNING **: 14:50:20.686: Ignoring unrecognized CSS property: vertical-align
#
# ** (org.inkscape.Inkscape:77827): WARNING **: 14:50:20.686: Ignoring unrecognized CSS property: vertical-align
#
# ** (org.inkscape.Inkscape:77816): WARNING **: 14:50:20.686: Ignoring unrecognized CSS property: vertical-align
#
# ** (org.inkscape.Inkscape:77834): WARNING **: 14:50:20.686: Ignoring unrecognized CSS property: vertical-align
#
# ** (org.inkscape.Inkscape:77837): WARNING **: 14:50:20.687: Ignoring unrecognized CSS property: vertical-align
#
# ** (org.inkscape.Inkscape:77838): WARNING **: 14:50:20.687: Ignoring unrecognized CSS property: vertical-align
#
# ** (org.inkscape.Inkscape:77832): WARNING **: 14:50:20.687: Ignoring unrecognized CSS property: vertical-align
#
# ** (org.inkscape.Inkscape:77823): WARNING **: 14:50:20.689: Ignoring unrecognized CSS property: vertical-align
#
# ** (org.inkscape.Inkscape:77840): WARNING **: 14:50:20.691: Ignoring unrecognized CSS property: vertical-align
#
# ** (org.inkscape.Inkscape:77856): WARNING **: 14:50:20.695: Ignoring unrecognized CSS property: vertical-align
# Background RRGGBBAA: ffffffff
# Area 0:0:18173.1:2085 exported to 512 x 64 pixels (2.70466 dpi)
# Background RRGGBBAA: ffffffff
# Area 0:0:16314.8:1439.2 exported to 512 x 64 pixels (3.01272 dpi)
# Background RRGGBBAA: ffffffff
# Area 0:0:19454.1:2228.5 exported to 512 x 64 pixels (2.52656 dpi)
# Background RRGGBBAA: ffffffff
# Area 0:0:13236.2:2228.5 exported to 512 x 64 pixels (3.71345 dpi)
# Background RRGGBBAA: ffffffff
# Area 0:0:31808.8:2085 exported to 512 x 64 pixels (1.54523 dpi)
# Background RRGGBBAA: ffffffff
# Area 0:0:11729.5:2515.6 exported to 512 x 64 pixels (4.19046 dpi)
# Background RRGGBBAA: ffffffff
# Area 0:0:32324:2874.4 exported to 512 x 64 pixels (1.5206 dpi)
# Background RRGGBBAA: ffffffff
# Area 0:0:23929.5:2085 exported to 512 x 64 pixels (2.05403 dpi)
# Background RRGGBBAA: ffffffff
# Area 0:0:6767:1510.9 exported to 512 x 64 pixels (7.26348 dpi)
# Background RRGGBBAA: ffffffff
# Area 0:0:35461.9:2300.3 exported to 512 x 64 pixels (1.38605 dpi)
# Background RRGGBBAA: ffffffff
# Area 0:0:22146.5:2659.1 exported to 512 x 64 pixels (2.2194 dpi)
# Background RRGGBBAA: ffffffff
# Area 0:0:25886:3448.4 exported to 512 x 64 pixels (1.89879 dpi)
#
# ** (org.inkscape.Inkscape:77839): WARNING **: 14:50:20.724: Ignoring unrecognized CSS property: vertical-align
#
# ** (org.inkscape.Inkscape:77799): WARNING **: 14:50:20.725: Ignoring unrecognized CSS property: vertical-align
# Background RRGGBBAA: ffffffff
# Area 0:0:12015.1:2228.5 exported to 512 x 64 pixels (4.09085 dpi)
# Background RRGGBBAA: ffffffff
# Area 0:0:21811.3:1367.4 exported to 512 x 64 pixels (2.25351 dpi)
#
# ** (org.inkscape.Inkscape:77842): WARNING **: 14:50:20.786: Ignoring unrecognized CSS property: vertical-align
# Background RRGGBBAA: ffffffff
# Area 0:0:13195.6:1080.4 exported to 512 x 64 pixels (3.72488 dpi)
#
# ** (org.inkscape.Inkscape:77844): WARNING **: 14:50:20.865: Ignoring unrecognized CSS property: vertical-align
#
# ** (org.inkscape.Inkscape:77845): WARNING **: 14:50:20.869: Ignoring unrecognized CSS property: vertical-align
# Background RRGGBBAA: ffffffff
# Area 0:0:17939.3:1223.9 exported to 512 x 64 pixels (2.73991 dpi)
# Background RRGGBBAA: ffffffff
# Area 0:0:18930.5:1726.2 exported to 512 x 64 pixels (2.59644 dpi)
#
# ** (org.inkscape.Inkscape:77851): WARNING **: 14:50:20.887: Ignoring unrecognized CSS property: vertical-align
# Background RRGGBBAA: ffffffff
# Area 0:0:17070.1:1295.7 exported to 512 x 64 pixels (2.87942 dpi)
#
# ** (org.inkscape.Inkscape:77848): WARNING **: 14:50:20.905: Ignoring unrecognized CSS property: vertical-align
#
# ** (org.inkscape.Inkscape:77847): WARNING **: 14:50:20.905: Ignoring unrecognized CSS property: vertical-align
# Background RRGGBBAA: ffffffff
# Area 0:0:16063.3:2659.1 exported to 512 x 64 pixels (3.05989 dpi)
# Background RRGGBBAA: ffffffff
# Area 0:0:27156.7:3448.4 exported to 512 x 64 pixels (1.80994 dpi)
#
# ** (org.inkscape.Inkscape:77801): WARNING **: 14:50:20.918: Ignoring unrecognized CSS property: vertical-align
# Background RRGGBBAA: ffffffff
# Area 0:0:7125.9:1223.9 exported to 512 x 64 pixels (6.89766 dpi)
#
# ** (org.inkscape.Inkscape:77850): WARNING **: 14:50:20.988: Ignoring unrecognized CSS property: vertical-align
# Background RRGGBBAA: ffffffff
# Area 0:0:15135.9:2228.5 exported to 512 x 64 pixels (3.24738 dpi)
#
# ** (org.inkscape.Inkscape:77829): WARNING **: 14:50:21.189: Ignoring unrecognized CSS property: vertical-align
#
# ** (org.inkscape.Inkscape:77833): WARNING **: 14:50:21.190: Ignoring unrecognized CSS property: vertical-align
# Background RRGGBBAA: ffffffff
# Area 0:0:7789.8:1367.4 exported to 512 x 64 pixels (6.30979 dpi)
# Background RRGGBBAA: ffffffff
# Area 0:0:20747.4:3161.4 exported to 512 x 64 pixels (2.36907 dpi)
#
# ** (org.inkscape.Inkscape:77843): WARNING **: 14:50:21.211: Ignoring unrecognized CSS property: vertical-align
#
# ** (org.inkscape.Inkscape:77835): WARNING **: 14:50:21.212: Ignoring unrecognized CSS property: vertical-align
# Background RRGGBBAA: ffffffff
# Area 0:0:7704.4:2300.3 exported to 512 x 64 pixels (6.37973 dpi)
# Background RRGGBBAA: ffffffff
# Area 0:0:32927.4:2515.6 exported to 512 x 64 pixels (1.49274 dpi)
#
# ** (org.inkscape.Inkscape:77857): WARNING **: 14:50:21.231: Ignoring unrecognized CSS property: vertical-align
#
# ** (org.inkscape.Inkscape:77846): WARNING **: 14:50:21.240: Ignoring unrecognized CSS property: vertical-align
#
# ** (org.inkscape.Inkscape:77818): WARNING **: 14:50:21.240: Ignoring unrecognized CSS property: vertical-align
#
# ** (org.inkscape.Inkscape:77820): WARNING **: 14:50:21.240: Ignoring unrecognized CSS property: vertical-align
# Background RRGGBBAA: ffffffff
# Area 0:0:18565.6:2659.1 exported to 512 x 64 pixels (2.64748 dpi)
# Background RRGGBBAA: ffffffff
# Area 0:0:28356.2:1510.9 exported to 512 x 64 pixels (1.73338 dpi)
# Background RRGGBBAA: ffffffff
# Area 0:0:24412.6:3233.2 exported to 512 x 64 pixels (2.01339 dpi)
# Background RRGGBBAA: ffffffff
# Area 0:0:35790.9:11987.8 exported to 512 x 64 pixels (1.37331 dpi)
#
# ** (org.inkscape.Inkscape:77841): WARNING **: 14:50:21.299: Ignoring unrecognized CSS property: vertical-align
# Background RRGGBBAA: ffffffff
# Area 0:0:24700.5:1367.4 exported to 512 x 64 pixels (1.98992 dpi)
#
# ** (org.inkscape.Inkscape:77858): WARNING **: 14:50:21.386: Ignoring unrecognized CSS property: vertical-align
# Background RRGGBBAA: ffffffff
# Area 0:0:6127.1:2085 exported to 512 x 64 pixels (8.02207 dpi)
# Generated 69 images from formulas
# ** (org.inkscape.Inkscape:77853): WARNING **: 14:50:21.483: Ignoring unrecognized CSS property: vertical-align
# Background RRGGBBAA: ffffffff
# Area 0:0:17580.4:3376.7 exported to 512 x 64 pixels (2.79584 dpi)
#
# ** (org.inkscape.Inkscape:77836): WARNING **: 14:50:21.499: Ignoring unrecognized CSS property: vertical-align
# Background RRGGBBAA: ffffffff
# Area 0:0:8511:2802.6 exported to 512 x 64 pixels (5.77511 dpi)
#
# ** (org.inkscape.Inkscape:77805): WARNING **: 14:50:21.518: Ignoring unrecognized CSS property: vertical-align
#
# ** (org.inkscape.Inkscape:77808): WARNING **: 14:50:21.523: Ignoring unrecognized CSS property: vertical-align
# Background RRGGBBAA: ffffffff
# Area 0:0:18163.2:2443.8 exported to 512 x 64 pixels (2.70613 dpi)
# Background RRGGBBAA: ffffffff
# Area 0:0:12289.7:1510.9 exported to 512 x 64 pixels (3.99945 dpi)
#
# ** (org.inkscape.Inkscape:77860): WARNING **: 14:50:21.542: Ignoring unrecognized CSS property: vertical-align
# Background RRGGBBAA: ffffffff
# Area 0:0:5781.2:1582.7 exported to 512 x 64 pixels (8.50204 dpi)
#
# ** (org.inkscape.Inkscape:77849): WARNING **: 14:50:21.571: Ignoring unrecognized CSS property: vertical-align
# Background RRGGBBAA: ffffffff
# Area 0:0:13117.5:1654.5 exported to 512 x 64 pixels (3.74706 dpi)
#
# ** (org.inkscape.Inkscape:77810): WARNING **: 14:50:21.604: Ignoring unrecognized CSS property: vertical-align
# Background RRGGBBAA: ffffffff
# Area 0:0:7842.4:1223.9 exported to 512 x 64 pixels (6.26747 dpi)
# Warning: Option --without-gui= is deprecated
#
# ** (org.inkscape.Inkscape:77862): WARNING **: 14:50:21.687: Ignoring unrecognized CSS property: vertical-align
# Background RRGGBBAA: ffffffff
# Area 0:0:27373:3807.2 exported to 512 x 64 pixels (1.79564 dpi)
#
# ** (org.inkscape.Inkscape:77809): WARNING **: 14:50:21.713: Ignoring unrecognized CSS property: vertical-align
# Background RRGGBBAA: ffffffff
# Area 0:0:12708.1:3089.6 exported to 512 x 64 pixels (3.86777 dpi)
#
# ** (org.inkscape.Inkscape:77859): WARNING **: 14:50:21.736: Ignoring unrecognized CSS property: vertical-align
# Background RRGGBBAA: ffffffff
# Area 0:0:10225.3:1223.9 exported to 512 x 64 pixels (4.8069 dpi)
#
# ** (org.inkscape.Inkscape:77852): WARNING **: 14:50:21.781: Ignoring unrecognized CSS property: vertical-align
# Background RRGGBBAA: ffffffff
# Area 0:0:7421.3:1654.5 exported to 512 x 64 pixels (6.6231 dpi)
#
# ** (org.inkscape.Inkscape:77855): WARNING **: 14:50:21.804: Ignoring unrecognized CSS property: vertical-align
# Background RRGGBBAA: ffffffff
# Area 0:0:17022.7:1295.7 exported to 512 x 64 pixels (2.88744 dpi)
# Warning: Option --without-gui= is deprecated
#
# ** (org.inkscape.Inkscape:77822): WARNING **: 14:50:21.846: Ignoring unrecognized CSS property: vertical-align
#
# ** (org.inkscape.Inkscape:77854): WARNING **: 14:50:21.847: Ignoring unrecognized CSS property: vertical-align
# Background RRGGBBAA: ffffffff
# Area 0:0:15672.2:1439.2 exported to 512 x 64 pixels (3.13625 dpi)
# Background RRGGBBAA: ffffffff
# Area 0:0:27625.8:1439.2 exported to 512 x 64 pixels (1.77921 dpi)
#
# ** (org.inkscape.Inkscape:77821): WARNING **: 14:50:21.880: Ignoring unrecognized CSS property: vertical-align
#
# ** (org.inkscape.Inkscape:77806): WARNING **: 14:50:21.894: Ignoring unrecognized CSS property: vertical-align
# Background RRGGBBAA: ffffffff
# Area 0:0:9785.1:1223.9 exported to 512 x 64 pixels (5.02315 dpi)
# Background RRGGBBAA: ffffffff
# Area 0:0:34397.3:4094.3 exported to 512 x 64 pixels (1.42895 dpi)
#
# ** (org.inkscape.Inkscape:77819): WARNING **: 14:50:21.919: Ignoring unrecognized CSS property: vertical-align
# Background RRGGBBAA: ffffffff
# Area 0:0:6989.2:1439.2 exported to 512 x 64 pixels (7.03256 dpi)
#
# ** (org.inkscape.Inkscape:77807): WARNING **: 14:50:21.926: Ignoring unrecognized CSS property: vertical-align
# Background RRGGBBAA: ffffffff
# Area 0:0:5306.2:1367.4 exported to 512 x 64 pixels (9.26313 dpi)
# Warning: Option --without-gui= is deprecated
#
# ** (org.inkscape.Inkscape:77815): WARNING **: 14:50:21.952: Ignoring unrecognized CSS property: vertical-align
# Background RRGGBBAA: ffffffff
# Area 0:0:7141.3:2372 exported to 512 x 64 pixels (6.88278 dpi)
# Warning: Option --without-gui= is deprecated
#
# ** (org.inkscape.Inkscape:77813): WARNING **: 14:50:22.038: Ignoring unrecognized CSS property: vertical-align
# Background RRGGBBAA: ffffffff
# Area 0:0:15935.5:1223.9 exported to 512 x 64 pixels (3.08443 dpi)
#
# ** (org.inkscape.Inkscape:77826): WARNING **: 14:50:22.062: Ignoring unrecognized CSS property: vertical-align
# Background RRGGBBAA: ffffffff
# Area 0:0:8161.1:3950.7 exported to 512 x 64 pixels (6.02272 dpi)
# Warning: Option --without-gui= is deprecated
# Warning: Option --without-gui= is deprecated
#
# ** (org.inkscape.Inkscape:77804): WARNING **: 14:50:22.145: Ignoring unrecognized CSS property: vertical-align
# Background RRGGBBAA: ffffffff
# Area 0:0:10013.1:1223.9 exported to 512 x 64 pixels (4.90877 dpi)
#
# ** (org.inkscape.Inkscape:77831): WARNING **: 14:50:22.173: Ignoring unrecognized CSS property: vertical-align
# Background RRGGBBAA: ffffffff
# Area 0:0:15376.3:1439.2 exported to 512 x 64 pixels (3.19661 dpi)
#
# ** (org.inkscape.Inkscape:77828): WARNING **: 14:50:22.194: Ignoring unrecognized CSS property: vertical-align
# Background RRGGBBAA: ffffffff
# Area 0:0:10582.7:2587.3 exported to 512 x 64 pixels (4.64456 dpi)
#
# ** (org.inkscape.Inkscape:77802): WARNING **: 14:50:22.211: Ignoring unrecognized CSS property: vertical-align
#
# ** (org.inkscape.Inkscape:77798): WARNING **: 14:50:22.218: Ignoring unrecognized CSS property: vertical-align
# Background RRGGBBAA: ffffffff
# Area 0:0:23067:2372 exported to 512 x 64 pixels (2.13084 dpi)
# Background RRGGBBAA: ffffffff
# Area 0:0:19086.9:3233.2 exported to 512 x 64 pixels (2.57517 dpi)
#
# ** (org.inkscape.Inkscape:77861): WARNING **: 14:50:22.247: Ignoring unrecognized CSS property: vertical-align
# Background RRGGBBAA: ffffffff
# Area 0:0:29133.3:1582.7 exported to 512 x 64 pixels (1.68714 dpi)
#
# ** (org.inkscape.Inkscape:77812): WARNING **: 14:50:22.287: Ignoring unrecognized CSS property: vertical-align
# Background RRGGBBAA: ffffffff
# Area 0:0:23667:1798 exported to 512 x 64 pixels (2.07682 dpi)
#
# ** (org.inkscape.Inkscape:77830): WARNING **: 14:50:22.358: Ignoring unrecognized CSS property: vertical-align
# Background RRGGBBAA: ffffffff
# Area 0:0:11039.7:1439.2 exported to 512 x 64 pixels (4.45229 dpi)
#
# ** (org.inkscape.Inkscape:77872): WARNING **: 14:50:22.375: Ignoring unrecognized CSS property: vertical-align
# Background RRGGBBAA: ffffffff
# Area 0:0:21189.5:1439.2 exported to 512 x 64 pixels (2.31964 dpi)
#
# ** (org.inkscape.Inkscape:77869): WARNING **: 14:50:22.427: Ignoring unrecognized CSS property: margin-bottom
#
# ** (org.inkscape.Inkscape:77869): WARNING **: 14:50:22.427: Ignoring unrecognized CSS property: vertical-align
# Background RRGGBBAA: ffffffff
# Area 0:0:26624.3:4237.8 exported to 512 x 64 pixels (1.84613 dpi)
#
# ** (org.inkscape.Inkscape:77824): WARNING **: 14:50:22.440: Ignoring unrecognized CSS property: vertical-align
# Background RRGGBBAA: ffffffff
# Area 0:0:14093.7:1080.4 exported to 512 x 64 pixels (3.48752 dpi)
#
# ** (org.inkscape.Inkscape:77811): WARNING **: 14:50:22.470: Ignoring unrecognized CSS property: vertical-align
# Background RRGGBBAA: ffffffff
# Area 0:0:5369.8:2443.8 exported to 512 x 64 pixels (9.15341 dpi)
#
# ** (org.inkscape.Inkscape:77814): WARNING **: 14:50:22.485: Ignoring unrecognized CSS property: vertical-align
# Background RRGGBBAA: ffffffff
# Area 0:0:11023.1:1295.7 exported to 512 x 64 pixels (4.459 dpi)
#
# ** (org.inkscape.Inkscape:77870): WARNING **: 14:50:22.565: Ignoring unrecognized CSS property: vertical-align
# Background RRGGBBAA: ffffffff
# Area 0:0:15690.1:3520.2 exported to 512 x 64 pixels (3.13268 dpi)
#
# ** (org.inkscape.Inkscape:77866): WARNING **: 14:50:22.610: Ignoring unrecognized CSS property: vertical-align
# Background RRGGBBAA: ffffffff
# Area 0:0:10760.8:1295.7 exported to 512 x 64 pixels (4.56769 dpi)
#
# ** (org.inkscape.Inkscape:77867): WARNING **: 14:50:22.627: Ignoring unrecognized CSS property: vertical-align
# Background RRGGBBAA: ffffffff
# Area 0:0:17119:2443.8 exported to 512 x 64 pixels (2.8712 dpi)
#
# ** (org.inkscape.Inkscape:77871): WARNING **: 14:50:22.661: Ignoring unrecognized CSS property: vertical-align
# Background RRGGBBAA: ffffffff
# Area 0:0:21606:2515.6 exported to 512 x 64 pixels (2.27492 dpi)
